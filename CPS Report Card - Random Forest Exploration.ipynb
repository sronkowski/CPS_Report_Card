# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
import pandas as pd
import numpy as np
#from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from IPython.display import display

from sklearn import metrics

# %%
PATH = "C:/Users/sronkowski/Documents/GitHub/CPS_Report_Card/"
#PATH = "/home/steve/Code/CPS_Report_Card/"

# %% [markdown]
# # Step 1 - Data Cleaning and Preprocessing
# To begin the anaysis, I will load four years worth of Report Card data into seperate DataFrames.

# %%
df_201516 = pd.read_csv(f'{PATH}Chicago_Public_Schools_-_School_Progress_Reports_SY1516.csv', 
                     low_memory=False, na_values = ["NOT ENOUGH DATA", "NOT APPLICABLE", "INCOMPLETE DATA"])
df_201516.shape
# Out:
# (670, 153)

# %%
df_201617 = pd.read_csv(f'{PATH}Chicago_Public_Schools_-_School_Progress_Reports_SY1617.csv', 
                     low_memory=False, na_values = ["NOT ENOUGH DATA", "NOT APPLICABLE", "INCOMPLETE DATA"])
df_201617.shape
# Out:
# (661, 161)

# %%
df_201718 = pd.read_csv(f'{PATH}Chicago_Public_Schools_-_School_Progress_Reports_SY1718.csv', 
                     low_memory=False, na_values = ["NOT ENOUGH DATA", "NOT APPLICABLE", "INCOMPLETE DATA"])
df_201718.shape
# Out:
# (661, 163)

# %%
df_201819 = pd.read_csv(f'{PATH}Chicago_Public_Schools_-_School_Progress_Reports_SY1819.csv', 
                     low_memory=False, na_values = ["NOT ENOUGH DATA", "NOT APPLICABLE", "INCOMPLETE DATA"])
df_201819.shape
# Out:
# (654, 182)

# %% [markdown]
# With the raw data now loaded into memory, I will review the data as formatted to remove any columns that are redundant, merely descriptive, or otherwise hold no predictive value.  First, however, I will implement a basic `display_all()` function to get full-row readouts of the DataFrames.

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

# %%
display_all(df_201516.tail().T)
# Out:
#                                                                                            665  \
# School_ID                                                                               610173
# Short_Name                                                                            SHERWOOD
# Long_Name                                                     Jesse Sherwood Elementary School
# School_Type                                                                       Neighborhood
# Primary_Category                                                                            ES
# Address                                                                          245 W 57TH ST
# City                                                                                   Chicago
# State                                                                                 Illinois
# Zip                                                                                      60621
# Phone                                                                              7.73535e+09
# Fax                                                                                7.73535e+09
# CPS_School_Profile                           http://cps.edu/Schools/Pages/school.aspx?Schoo...
# Website                                                            http://www.sherwood.cps.edu
# Progress_Report_Year                                                                      2015
# Blue_Ribbon_Award_Year                                                                     NaN
# Excelerate_Award_Gold_Year                                                                 NaN
# Spot_Light_Award_Year                                                                      NaN
# Improvement_Award_Year                                                                     NaN
# Excellence_Award_Year                                                                      NaN
# Student_Growth_Rating                                                        FAR ABOVE AVERAGE
# Student_Growth_Description                   Student Growth measures the change in standard...
# Growth_Reading_Grades_Tested_Pct_ES                                                         99
# Growth_Reading_Grades_Tested_Label_ES                                                     99th
# Growth_Math_Grades_Tested_Pct_ES                                                            99
# Growth_Math_Grades_Tested_Label_ES                                                        99th
# Student_Attainment_Rating                                                    FAR ABOVE AVERAGE
# Student_Attainment_Description               Student Attainment measures how well the schoo...
# Attainment_Reading_Pct_ES                                                                   96
# Attainment_Reading_Lbl_ES                                                                 96th
# Attainment_Math_Pct_ES                                                                      93
# Attainment_Math_Lbl_ES                                                                    93rd
# Culture_Climate_Rating                                                          WELL ORGANIZED
# Culture_Climate_Description                  Results are based on student and teacher respo...
# School_Survey_Student_Response_Rate_Pct                                                   99.9
# School_Survey_Student_Response_Rate_Avg_Pct                                               81.2
# School_Survey_Teacher_Response_Rate_Pct                                                   95.8
# School_Survey_Teacher_Response_Rate_Avg_Pct                                               80.7
# Healthy_School_Certification                                                     NOT CERTIFIED
# Healthy_School_Certification_Description     This school has not achieved Healthy School Ce...
# Creative_School_Certification                                                        EXCELLING
# Creative_School_Certification_Description    This school is Excelling in the arts. It meets...
# NWEA_Reading_Growth_Grade_3_Pct                                                             99
# NWEA_Reading_Growth_Grade_3_Lbl                                                           99th
# NWEA_Reading_Growth_Grade_4_Pct                                                             99
# NWEA_Reading_Growth_Grade_4_Lbl                                                           99th
# NWEA_Reading_Growth_Grade_5_Pct                                                             99
# NWEA_Reading_Growth_Grade_5_Lbl                                                           99th
# NWEA_Reading_Growth_Grade_6_Pct                                                             99
# NWEA_Reading_Growth_Grade_6_Lbl                                                           99th
# NWEA_Reading_Growth_Grade_7_Pct                                                             99
# NWEA_Reading_Growth_Grade_7_Lbl                                                           99th
# NWEA_Reading_Growth_Grade_8_Pct                                                             79
# NWEA_Reading_Growth_Grade_8_Lbl                                                           79th
# NWEA_Math_Growth_Grade_3_Pct                                                                99
# NWEA_Math_Growth_Grade_3_Lbl                                                              99th
# NWEA_Math_Growth_Grade_4_Pct                                                                99
# NWEA_Math_Growth_Grade_4_Lbl                                                              99th
# NWEA_Math_Growth_Grade_5_Pct                                                                99
# NWEA_Math_Growth_Grade_5_Lbl                                                              99th
# NWEA_Math_Growth_Grade_6_Pct                                                                99
# NWEA_Math_Growth_Grade_6_Lbl                                                              99th
# NWEA_Math_Growth_Grade_7_Pct                                                                99
# NWEA_Math_Growth_Grade_7_Lbl                                                              99th
# NWEA_Math_Growth_Grade_8_Pct                                                                99
# NWEA_Math_Growth_Grade_8_Lbl                                                              99th
# NWEA_Reading_Attainment_Grade_2_Pct                                                         95
# NWEA_Reading_Attainment_Grade_2_Lbl                                                       95th
# NWEA_Reading_Attainment_Grade_3_Pct                                                         86
# NWEA_Reading_Attainment_Grade_3_Lbl                                                       86th
# NWEA_Reading_Attainment_Grade_4_Pct                                                         99
# NWEA_Reading_Attainment_Grade_4_Lbl                                                       99th
# NWEA_Reading_Attainment_Grade_5_Pct                                                         97
# NWEA_Reading_Attainment_Grade_5_Lbl                                                       97th
# NWEA_Reading_Attainment_Grade_6_Pct                                                         88
# NWEA_Reading_Attainment_Grade_6_Lbl                                                       88th
# NWEA_Reading_Attainment_Grade_7_Pct                                                         73
# NWEA_Reading_Attainment_Grade_7_Lbl                                                       73rd
# NWEA_Reading_Attainment_Grade_8_Pct                                                         58
# NWEA_Reading_Attainment_Grade_8_Lbl                                                       58th
# NWEA_Math_Attainment_Grade_2_Pct                                                            99
# NWEA_Math_Attainment_Grade_2_Lbl                                                          99th
# NWEA_Math_Attainment_Grade_3_Pct                                                            82
# NWEA_Math_Attainment_Grade_3_Lbl                                                          82nd
# NWEA_Math_Attainment_Grade_4_Pct                                                            99
# NWEA_Math_Attainment_Grade_4_Lbl                                                          99th
# NWEA_Math_Attainment_Grade_5_Pct                                                            75
# NWEA_Math_Attainment_Grade_5_Lbl                                                          75th
# NWEA_Math_Attainment_Grade_6_Pct                                                            82
# NWEA_Math_Attainment_Grade_6_Lbl                                                          82nd
# NWEA_Math_Attainment_Grade_7_Pct                                                            88
# NWEA_Math_Attainment_Grade_7_Lbl                                                          88th
# NWEA_Math_Attainment_Grade_8_Pct                                                            74
# NWEA_Math_Attainment_Grade_8_Lbl                                                          74th
# School_Survey_Involved_Families                                                        NEUTRAL
# School_Survey_Supportive_Environment                                               VERY STRONG
# School_Survey_Ambitious_Instruction                                                VERY STRONG
# School_Survey_Effective_Leaders                                                         STRONG
# School_Survey_Collaborative_Teachers                                                    STRONG
# School_Survey_Safety                                                                    STRONG
# Suspensions_Per_100_Students_Year_1_Pct                                                    5.8
# Suspensions_Per_100_Students_Year_2_Pct                                                    1.7
# Suspensions_Per_100_Students_Avg_Pct                                                       3.8
# Misconducts_To_Suspensions_Year_1_Pct                                                     62.2
# Misconducts_To_Suspensions_Year_2_Pct                                                     18.2
# Misconducts_To_Suspensions_Avg_Pct                                                        18.4
# Average_Length_Suspension_Year_1_Pct                                                  2.7 days
# Average_Length_Suspension_Year_2_Pct                                                  2.7 days
# Average_Length_Suspension_Avg_Pct                                                     2.1 days
# Behavior_Discipline_Year_1                                                                2014
# Behavior_Discipline_Year_2                                                                2015
# School_Survey_School_Community                                                          Strong
# School_Survey_Parent_Teacher_Partnership                                               Neutral
# School_Survey_Quality_Of_Facilities                                                     Strong
# Student_Attendance_Year_1_Pct                                                               95
# Student_Attendance_Year_2_Pct                                                             95.9
# Student_Attendance_Avg_Pct                                                                95.1
# Teacher_Attendance_Year_1_Pct                                                             97.6
# Teacher_Attendance_Year_2_Pct                                                             96.3
# Teacher_Attendance_Avg_Pct                                                                  95
# One_Year_Dropout_Rate_Year_1_Pct                                                           NaN
# One_Year_Dropout_Rate_Year_2_Pct                                                           NaN
# One_Year_Dropout_Rate_Avg_Pct                                                              7.9
# Other_Metrics_Year_1                                                                      2014
# Other_Metrics_Year_2                                                                      2015
# Growth_ACT_Grade_11_Pct                                                                    NaN
# Growth_ACT_Grade_11_Lbl                                                                    NaN
# Attainment_ACT_Grade_11_Pct                                                                NaN
# Attainment_ACT_Grade_11_Lbl                                                                NaN
# Freshmen_On_Track_School_Pct_Year_2                                                        NaN
# Freshmen_On_Track_CPS_Pct_Year_2                                                          84.1
# Freshmen_On_Track_School_Pct_Year_1                                                        NaN
# Freshmen_On_Track_CPS_Pct_Year_1                                                          82.6
# College_Enrollment_School_Pct_Year_2                                                       NaN
# College_Enrollment_CPS_Pct_Year_2                                                         58.7
# College_Enrollment_School_Pct_Year_1                                                       NaN
# College_Enrollment_CPS_Pct_Year_1                                                         58.1
# College_Persistence_School_Pct_Year_2                                                      NaN
# College_Persistence_CPS_Pct_Year_2                                                          70
# College_Persistence_School_Pct_Year_1                                                      NaN
# College_Persistence_CPS_Pct_Year_1                                                        70.1
# Progress_Toward_Graduation_Year_1                                                         2014
# Progress_Toward_Graduation_Year_2                                                         2015
# State_School_Report_Card_URL                 http://iirc.niu.edu/School.aspx?schoolid=15016...
# Mobility_Rate_Pct                                                                         32.3
# Chronic_Truancy_Pct                                                                        NaN
# Empty_Progress_Report_Message                This School Progress Report is currently under...
# School_Survey_Rating_Description             This school is “Well-Organized for Improvement...
# Supportive_School_Award                                                              NOT RATED
# Supportive_School_Award_Desc                 This school is in the process of being reviewe...
# Parent_Survey_Results_Year                                                                2015
# School_Latitude                                                                        41.7908
# School_Longitude                                                                      -87.6323
# Location                                     245 W 57TH ST\r\nChicago, Illinois 60621\r\n(4...
#
#                                                                                            666  \
# School_ID                                                                               610115
# Short_Name                                                                          PARK MANOR
# Long_Name                                                         Park Manor Elementary School
# School_Type                                                                       Neighborhood
# Primary_Category                                                                            ES
# Address                                                                      7037 S RHODES AVE
# City                                                                                   Chicago
# State                                                                                 Illinois
# Zip                                                                                      60637
# Phone                                                                              7.73535e+09
# Fax                                                                                7.73535e+09
# CPS_School_Profile                           http://cps.edu/Schools/Pages/school.aspx?Schoo...
# Website                                                        http://parkmanorelementary.org/
# Progress_Report_Year                                                                      2015
# Blue_Ribbon_Award_Year                                                                     NaN
# Excelerate_Award_Gold_Year                                                                 NaN
# Spot_Light_Award_Year                                                                      NaN
# Improvement_Award_Year                                                                    2012
# Excellence_Award_Year                                                                      NaN
# Student_Growth_Rating                                                                  AVERAGE
# Student_Growth_Description                   Student Growth measures the change in standard...
# Growth_Reading_Grades_Tested_Pct_ES                                                         43
# Growth_Reading_Grades_Tested_Label_ES                                                     43rd
# Growth_Math_Grades_Tested_Pct_ES                                                            31
# Growth_Math_Grades_Tested_Label_ES                                                        31st
# Student_Attainment_Rating                                                        BELOW AVERAGE
# Student_Attainment_Description               Student Attainment measures how well the schoo...
# Attainment_Reading_Pct_ES                                                                   24
# Attainment_Reading_Lbl_ES                                                                 24th
# Attainment_Math_Pct_ES                                                                      25
# Attainment_Math_Lbl_ES                                                                    25th
# Culture_Climate_Rating                                                          WELL ORGANIZED
# Culture_Climate_Description                  Results are based on student and teacher respo...
# School_Survey_Student_Response_Rate_Pct                                                   87.7
# School_Survey_Student_Response_Rate_Avg_Pct                                               81.2
# School_Survey_Teacher_Response_Rate_Pct                                                   73.7
# School_Survey_Teacher_Response_Rate_Avg_Pct                                               80.7
# Healthy_School_Certification                                                     NOT CERTIFIED
# Healthy_School_Certification_Description     This school has not achieved Healthy School Ce...
# Creative_School_Certification                                                       DEVELOPING
# Creative_School_Certification_Description    This school is Developing in the arts. It occa...
# NWEA_Reading_Growth_Grade_3_Pct                                                             66
# NWEA_Reading_Growth_Grade_3_Lbl                                                           66th
# NWEA_Reading_Growth_Grade_4_Pct                                                             74
# NWEA_Reading_Growth_Grade_4_Lbl                                                           74th
# NWEA_Reading_Growth_Grade_5_Pct                                                              3
# NWEA_Reading_Growth_Grade_5_Lbl                                                            3rd
# NWEA_Reading_Growth_Grade_6_Pct                                                             57
# NWEA_Reading_Growth_Grade_6_Lbl                                                           57th
# NWEA_Reading_Growth_Grade_7_Pct                                                             71
# NWEA_Reading_Growth_Grade_7_Lbl                                                           71st
# NWEA_Reading_Growth_Grade_8_Pct                                                             16
# NWEA_Reading_Growth_Grade_8_Lbl                                                           16th
# NWEA_Math_Growth_Grade_3_Pct                                                                 1
# NWEA_Math_Growth_Grade_3_Lbl                                                               1st
# NWEA_Math_Growth_Grade_4_Pct                                                                 2
# NWEA_Math_Growth_Grade_4_Lbl                                                               2nd
# NWEA_Math_Growth_Grade_5_Pct                                                                30
# NWEA_Math_Growth_Grade_5_Lbl                                                              30th
# NWEA_Math_Growth_Grade_6_Pct                                                                81
# NWEA_Math_Growth_Grade_6_Lbl                                                              81st
# NWEA_Math_Growth_Grade_7_Pct                                                                95
# NWEA_Math_Growth_Grade_7_Lbl                                                              95th
# NWEA_Math_Growth_Grade_8_Pct                                                                60
# NWEA_Math_Growth_Grade_8_Lbl                                                              60th
# NWEA_Reading_Attainment_Grade_2_Pct                                                         40
# NWEA_Reading_Attainment_Grade_2_Lbl                                                       40th
# NWEA_Reading_Attainment_Grade_3_Pct                                                         25
# NWEA_Reading_Attainment_Grade_3_Lbl                                                       25th
# NWEA_Reading_Attainment_Grade_4_Pct                                                         23
# NWEA_Reading_Attainment_Grade_4_Lbl                                                       23rd
# NWEA_Reading_Attainment_Grade_5_Pct                                                          7
# NWEA_Reading_Attainment_Grade_5_Lbl                                                        7th
# NWEA_Reading_Attainment_Grade_6_Pct                                                         30
# NWEA_Reading_Attainment_Grade_6_Lbl                                                       30th
# NWEA_Reading_Attainment_Grade_7_Pct                                                         58
# NWEA_Reading_Attainment_Grade_7_Lbl                                                       58th
# NWEA_Reading_Attainment_Grade_8_Pct                                                         19
# NWEA_Reading_Attainment_Grade_8_Lbl                                                       19th
# NWEA_Math_Attainment_Grade_2_Pct                                                            36
# NWEA_Math_Attainment_Grade_2_Lbl                                                          36th
# NWEA_Math_Attainment_Grade_3_Pct                                                             4
# NWEA_Math_Attainment_Grade_3_Lbl                                                           4th
# NWEA_Math_Attainment_Grade_4_Pct                                                             6
# NWEA_Math_Attainment_Grade_4_Lbl                                                           6th
# NWEA_Math_Attainment_Grade_5_Pct                                                            16
# NWEA_Math_Attainment_Grade_5_Lbl                                                          16th
# NWEA_Math_Attainment_Grade_6_Pct                                                            34
# NWEA_Math_Attainment_Grade_6_Lbl                                                          34th
# NWEA_Math_Attainment_Grade_7_Pct                                                            67
# NWEA_Math_Attainment_Grade_7_Lbl                                                          67th
# NWEA_Math_Attainment_Grade_8_Pct                                                            66
# NWEA_Math_Attainment_Grade_8_Lbl                                                          66th
# School_Survey_Involved_Families                                                         STRONG
# School_Survey_Supportive_Environment                                                    STRONG
# School_Survey_Ambitious_Instruction                                                VERY STRONG
# School_Survey_Effective_Leaders                                                         STRONG
# School_Survey_Collaborative_Teachers                                               VERY STRONG
# School_Survey_Safety                                                                      WEAK
# Suspensions_Per_100_Students_Year_1_Pct                                                    2.9
# Suspensions_Per_100_Students_Year_2_Pct                                                    3.7
# Suspensions_Per_100_Students_Avg_Pct                                                       3.8
# Misconducts_To_Suspensions_Year_1_Pct                                                     47.6
# Misconducts_To_Suspensions_Year_2_Pct                                                     48.3
# Misconducts_To_Suspensions_Avg_Pct                                                        18.4
# Average_Length_Suspension_Year_1_Pct                                                  3.0 days
# Average_Length_Suspension_Year_2_Pct                                                  3.1 days
# Average_Length_Suspension_Avg_Pct                                                     2.1 days
# Behavior_Discipline_Year_1                                                                2014
# Behavior_Discipline_Year_2                                                                2015
# School_Survey_School_Community                                                             NaN
# School_Survey_Parent_Teacher_Partnership                                                   NaN
# School_Survey_Quality_Of_Facilities                                                        NaN
# Student_Attendance_Year_1_Pct                                                               96
# Student_Attendance_Year_2_Pct                                                             96.1
# Student_Attendance_Avg_Pct                                                                95.1
# Teacher_Attendance_Year_1_Pct                                                             95.5
# Teacher_Attendance_Year_2_Pct                                                             96.1
# Teacher_Attendance_Avg_Pct                                                                  95
# One_Year_Dropout_Rate_Year_1_Pct                                                           NaN
# One_Year_Dropout_Rate_Year_2_Pct                                                           NaN
# One_Year_Dropout_Rate_Avg_Pct                                                              7.9
# Other_Metrics_Year_1                                                                      2014
# Other_Metrics_Year_2                                                                      2015
# Growth_ACT_Grade_11_Pct                                                                    NaN
# Growth_ACT_Grade_11_Lbl                                                                    NaN
# Attainment_ACT_Grade_11_Pct                                                                NaN
# Attainment_ACT_Grade_11_Lbl                                                                NaN
# Freshmen_On_Track_School_Pct_Year_2                                                        NaN
# Freshmen_On_Track_CPS_Pct_Year_2                                                          84.1
# Freshmen_On_Track_School_Pct_Year_1                                                        NaN
# Freshmen_On_Track_CPS_Pct_Year_1                                                          82.6
# College_Enrollment_School_Pct_Year_2                                                       NaN
# College_Enrollment_CPS_Pct_Year_2                                                         58.7
# College_Enrollment_School_Pct_Year_1                                                       NaN
# College_Enrollment_CPS_Pct_Year_1                                                         58.1
# College_Persistence_School_Pct_Year_2                                                      NaN
# College_Persistence_CPS_Pct_Year_2                                                          70
# College_Persistence_School_Pct_Year_1                                                      NaN
# College_Persistence_CPS_Pct_Year_1                                                        70.1
# Progress_Toward_Graduation_Year_1                                                         2014
# Progress_Toward_Graduation_Year_2                                                         2015
# State_School_Report_Card_URL                 http://iirc.niu.edu/School.aspx?schoolid=15016...
# Mobility_Rate_Pct                                                                         41.2
# Chronic_Truancy_Pct                                                                        NaN
# Empty_Progress_Report_Message                This School Progress Report is currently under...
# School_Survey_Rating_Description             This school is “Well-Organized for Improvement...
# Supportive_School_Award                                                              NOT RATED
# Supportive_School_Award_Desc                 This school is in the process of being reviewe...
# Parent_Survey_Results_Year                                                                2015
# School_Latitude                                                                        41.7665
# School_Longitude                                                                      -87.6115
# Location                                     7037 S RHODES AVE\r\nChicago, Illinois 60637\r...
#
#                                                                                            667  \
# School_ID                                                                               609996
# Short_Name                                                                              HOLDEN
# Long_Name                                                   Charles N Holden Elementary School
# School_Type                                                                       Neighborhood
# Primary_Category                                                                            ES
# Address                                                                         1104 W 31ST ST
# City                                                                                   Chicago
# State                                                                                 Illinois
# Zip                                                                                      60608
# Phone                                                                              7.73536e+09
# Fax                                                                                7.73536e+09
# CPS_School_Profile                           http://cps.edu/Schools/Pages/school.aspx?Schoo...
# Website                                                            http://www.Holdenschool.org
# Progress_Report_Year                                                                      2015
# Blue_Ribbon_Award_Year                                                                     NaN
# Excelerate_Award_Gold_Year                                                                2015
# Spot_Light_Award_Year                                                                      NaN
# Improvement_Award_Year                                                                     NaN
# Excellence_Award_Year                                                                      NaN
# Student_Growth_Rating                                                        FAR ABOVE AVERAGE
# Student_Growth_Description                   Student Growth measures the change in standard...
# Growth_Reading_Grades_Tested_Pct_ES                                                         71
# Growth_Reading_Grades_Tested_Label_ES                                                     71st
# Growth_Math_Grades_Tested_Pct_ES                                                            93
# Growth_Math_Grades_Tested_Label_ES                                                        93rd
# Student_Attainment_Rating                                                        ABOVE AVERAGE
# Student_Attainment_Description               Student Attainment measures how well the schoo...
# Attainment_Reading_Pct_ES                                                                   58
# Attainment_Reading_Lbl_ES                                                                 58th
# Attainment_Math_Pct_ES                                                                      81
# Attainment_Math_Lbl_ES                                                                    81st
# Culture_Climate_Rating                                                          WELL ORGANIZED
# Culture_Climate_Description                  Results are based on student and teacher respo...
# School_Survey_Student_Response_Rate_Pct                                                   88.6
# School_Survey_Student_Response_Rate_Avg_Pct                                               81.2
# School_Survey_Teacher_Response_Rate_Pct                                                   90.3
# School_Survey_Teacher_Response_Rate_Avg_Pct                                               80.7
# Healthy_School_Certification                                                     NOT CERTIFIED
# Healthy_School_Certification_Description     This school has not achieved Healthy School Ce...
# Creative_School_Certification                                                        EXCELLING
# Creative_School_Certification_Description    This school is Excelling in the arts. It meets...
# NWEA_Reading_Growth_Grade_3_Pct                                                             28
# NWEA_Reading_Growth_Grade_3_Lbl                                                           28th
# NWEA_Reading_Growth_Grade_4_Pct                                                             38
# NWEA_Reading_Growth_Grade_4_Lbl                                                           38th
# NWEA_Reading_Growth_Grade_5_Pct                                                             58
# NWEA_Reading_Growth_Grade_5_Lbl                                                           58th
# NWEA_Reading_Growth_Grade_6_Pct                                                             95
# NWEA_Reading_Growth_Grade_6_Lbl                                                           95th
# NWEA_Reading_Growth_Grade_7_Pct                                                             90
# NWEA_Reading_Growth_Grade_7_Lbl                                                           90th
# NWEA_Reading_Growth_Grade_8_Pct                                                             62
# NWEA_Reading_Growth_Grade_8_Lbl                                                           62nd
# NWEA_Math_Growth_Grade_3_Pct                                                                20
# NWEA_Math_Growth_Grade_3_Lbl                                                              20th
# NWEA_Math_Growth_Grade_4_Pct                                                                99
# NWEA_Math_Growth_Grade_4_Lbl                                                              99th
# NWEA_Math_Growth_Grade_5_Pct                                                                42
# NWEA_Math_Growth_Grade_5_Lbl                                                              42nd
# NWEA_Math_Growth_Grade_6_Pct                                                                83
# NWEA_Math_Growth_Grade_6_Lbl                                                              83rd
# NWEA_Math_Growth_Grade_7_Pct                                                                99
# NWEA_Math_Growth_Grade_7_Lbl                                                              99th
# NWEA_Math_Growth_Grade_8_Pct                                                                99
# NWEA_Math_Growth_Grade_8_Lbl                                                              99th
# NWEA_Reading_Attainment_Grade_2_Pct                                                         38
# NWEA_Reading_Attainment_Grade_2_Lbl                                                       38th
# NWEA_Reading_Attainment_Grade_3_Pct                                                         55
# NWEA_Reading_Attainment_Grade_3_Lbl                                                       55th
# NWEA_Reading_Attainment_Grade_4_Pct                                                         51
# NWEA_Reading_Attainment_Grade_4_Lbl                                                       51st
# NWEA_Reading_Attainment_Grade_5_Pct                                                         50
# NWEA_Reading_Attainment_Grade_5_Lbl                                                       50th
# NWEA_Reading_Attainment_Grade_6_Pct                                                         60
# NWEA_Reading_Attainment_Grade_6_Lbl                                                       60th
# NWEA_Reading_Attainment_Grade_7_Pct                                                         73
# NWEA_Reading_Attainment_Grade_7_Lbl                                                       73rd
# NWEA_Reading_Attainment_Grade_8_Pct                                                         66
# NWEA_Reading_Attainment_Grade_8_Lbl                                                       66th
# NWEA_Math_Attainment_Grade_2_Pct                                                            53
# NWEA_Math_Attainment_Grade_2_Lbl                                                          53rd
# NWEA_Math_Attainment_Grade_3_Pct                                                            43
# NWEA_Math_Attainment_Grade_3_Lbl                                                          43rd
# NWEA_Math_Attainment_Grade_4_Pct                                                            75
# NWEA_Math_Attainment_Grade_4_Lbl                                                          75th
# NWEA_Math_Attainment_Grade_5_Pct                                                            51
# NWEA_Math_Attainment_Grade_5_Lbl                                                          51st
# NWEA_Math_Attainment_Grade_6_Pct                                                            83
# NWEA_Math_Attainment_Grade_6_Lbl                                                          83rd
# NWEA_Math_Attainment_Grade_7_Pct                                                            97
# NWEA_Math_Attainment_Grade_7_Lbl                                                          97th
# NWEA_Math_Attainment_Grade_8_Pct                                                            97
# NWEA_Math_Attainment_Grade_8_Lbl                                                          97th
# School_Survey_Involved_Families                                                         STRONG
# School_Survey_Supportive_Environment                                                    STRONG
# School_Survey_Ambitious_Instruction                                                     STRONG
# School_Survey_Effective_Leaders                                                        NEUTRAL
# School_Survey_Collaborative_Teachers                                                    STRONG
# School_Survey_Safety                                                                   NEUTRAL
# Suspensions_Per_100_Students_Year_1_Pct                                                    4.4
# Suspensions_Per_100_Students_Year_2_Pct                                                      3
# Suspensions_Per_100_Students_Avg_Pct                                                       3.8
# Misconducts_To_Suspensions_Year_1_Pct                                                     61.5
# Misconducts_To_Suspensions_Year_2_Pct                                                     28.1
# Misconducts_To_Suspensions_Avg_Pct                                                        18.4
# Average_Length_Suspension_Year_1_Pct                                                  2.5 days
# Average_Length_Suspension_Year_2_Pct                                                  1.9 days
# Average_Length_Suspension_Avg_Pct                                                     2.1 days
# Behavior_Discipline_Year_1                                                                2014
# Behavior_Discipline_Year_2                                                                2015
# School_Survey_School_Community                                                         Neutral
# School_Survey_Parent_Teacher_Partnership                                               Neutral
# School_Survey_Quality_Of_Facilities                                                    Neutral
# Student_Attendance_Year_1_Pct                                                             94.5
# Student_Attendance_Year_2_Pct                                                             94.8
# Student_Attendance_Avg_Pct                                                                95.1
# Teacher_Attendance_Year_1_Pct                                                             95.5
# Teacher_Attendance_Year_2_Pct                                                             94.3
# Teacher_Attendance_Avg_Pct                                                                  95
# One_Year_Dropout_Rate_Year_1_Pct                                                           NaN
# One_Year_Dropout_Rate_Year_2_Pct                                                           NaN
# One_Year_Dropout_Rate_Avg_Pct                                                              7.9
# Other_Metrics_Year_1                                                                      2014
# Other_Metrics_Year_2                                                                      2015
# Growth_ACT_Grade_11_Pct                                                                    NaN
# Growth_ACT_Grade_11_Lbl                                                                    NaN
# Attainment_ACT_Grade_11_Pct                                                                NaN
# Attainment_ACT_Grade_11_Lbl                                                                NaN
# Freshmen_On_Track_School_Pct_Year_2                                                        NaN
# Freshmen_On_Track_CPS_Pct_Year_2                                                          84.1
# Freshmen_On_Track_School_Pct_Year_1                                                        NaN
# Freshmen_On_Track_CPS_Pct_Year_1                                                          82.6
# College_Enrollment_School_Pct_Year_2                                                       NaN
# College_Enrollment_CPS_Pct_Year_2                                                         58.7
# College_Enrollment_School_Pct_Year_1                                                       NaN
# College_Enrollment_CPS_Pct_Year_1                                                         58.1
# College_Persistence_School_Pct_Year_2                                                      NaN
# College_Persistence_CPS_Pct_Year_2                                                          70
# College_Persistence_School_Pct_Year_1                                                      NaN
# College_Persistence_CPS_Pct_Year_1                                                        70.1
# Progress_Toward_Graduation_Year_1                                                         2014
# Progress_Toward_Graduation_Year_2                                                         2015
# State_School_Report_Card_URL                 http://iirc.niu.edu/School.aspx?schoolid=15016...
# Mobility_Rate_Pct                                                                         14.2
# Chronic_Truancy_Pct                                                                        NaN
# Empty_Progress_Report_Message                This School Progress Report is currently under...
# School_Survey_Rating_Description             This school is “Well-Organized for Improvement...
# Supportive_School_Award                                                              NOT RATED
# Supportive_School_Award_Desc                 This school is in the process of being reviewe...
# Parent_Survey_Results_Year                                                                2015
# School_Latitude                                                                         41.838
# School_Longitude                                                                      -87.6538
# Location                                     1104 W 31ST ST\r\nChicago, Illinois 60608\r\n(...
#
#                                                                                            668  \
# School_ID                                                                               609815
# Short_Name                                                                             BOUCHET
# Long_Name                                           Edward A Bouchet Math & Science Academy ES
# School_Type                                                                       Neighborhood
# Primary_Category                                                                            ES
# Address                                                                    7355 S JEFFERY BLVD
# City                                                                                   Chicago
# State                                                                                 Illinois
# Zip                                                                                      60649
# Phone                                                                              7.73535e+09
# Fax                                                                                7.73535e+09
# CPS_School_Profile                           http://cps.edu/Schools/Pages/school.aspx?Schoo...
# Website                                                    http://www.bouchet-brynmawr.cps.edu
# Progress_Report_Year                                                                      2015
# Blue_Ribbon_Award_Year                                                                     NaN
# Excelerate_Award_Gold_Year                                                                 NaN
# Spot_Light_Award_Year                                                                      NaN
# Improvement_Award_Year                                                                     NaN
# Excellence_Award_Year                                                                      NaN
# Student_Growth_Rating                                                            ABOVE AVERAGE
# Student_Growth_Description                   Student Growth measures the change in standard...
# Growth_Reading_Grades_Tested_Pct_ES                                                         95
# Growth_Reading_Grades_Tested_Label_ES                                                     95th
# Growth_Math_Grades_Tested_Pct_ES                                                            67
# Growth_Math_Grades_Tested_Label_ES                                                        67th
# Student_Attainment_Rating                                                              AVERAGE
# ...
# Mobility_Rate_Pct                                                                         32.8
# Chronic_Truancy_Pct                                                                        NaN
# Empty_Progress_Report_Message                This School Progress Report is currently under...
# School_Survey_Rating_Description             This school is “Well-Organized for Improvement...
# Supportive_School_Award                                                              NOT RATED
# Supportive_School_Award_Desc                 This school is in the process of being reviewe...
# Parent_Survey_Results_Year                                                                2015
# School_Latitude                                                                        41.7608
# School_Longitude                                                                      -87.5761
# Location                                     7355 S JEFFERY BLVD\r\nChicago, Illinois 60649...
#
#                                                                                            669
# School_ID                                                                               400135
# Short_Name                                                                 YCCS - LATINO YOUTH
# Long_Name                                                     YCCS-Latino Youth Alternative HS
# School_Type                                                                            Charter
# Primary_Category                                                                            HS
# Address                                                                  2001 S CALIFORNIA AVE
# City                                                                                   Chicago
# State                                                                                 Illinois
# Zip                                                                                      60608
# Phone                                                                              7.73648e+09
# Fax                                                                                7.73648e+09
# CPS_School_Profile                           http://cps.edu/Schools/Pages/school.aspx?Schoo...
# Website                                                                                    NaN
# Progress_Report_Year                                                                      2015
# Blue_Ribbon_Award_Year                                                                     NaN
# Excelerate_Award_Gold_Year                                                                 NaN
# Spot_Light_Award_Year                                                                      NaN
# Improvement_Award_Year                                                                     NaN
# Excellence_Award_Year                                                                      NaN
# Student_Growth_Rating                                                        NO DATA AVAILABLE
# Student_Growth_Description                   Student Growth measures the change in standard...
# Growth_Reading_Grades_Tested_Pct_ES                                                        NaN
# Growth_Reading_Grades_Tested_Label_ES                                                      NaN
# Growth_Math_Grades_Tested_Pct_ES                                                           NaN
# Growth_Math_Grades_Tested_Label_ES                                                         NaN
# Student_Attainment_Rating                                                    FAR BELOW AVERAGE
# Student_Attainment_Description               Student Attainment measures how well the schoo...
# Attainment_Reading_Pct_ES                                                                  NaN
# Attainment_Reading_Lbl_ES                                                                  NaN
# Attainment_Math_Pct_ES                                                                     NaN
# Attainment_Math_Lbl_ES                                                                     NaN
# Culture_Climate_Rating                                                     PARTIALLY ORGANIZED
# Culture_Climate_Description                  Results are based on student and teacher respo...
# School_Survey_Student_Response_Rate_Pct                                                   64.1
# School_Survey_Student_Response_Rate_Avg_Pct                                               81.2
# School_Survey_Teacher_Response_Rate_Pct                                                   99.9
# School_Survey_Teacher_Response_Rate_Avg_Pct                                               80.7
# Healthy_School_Certification                                                     NOT CERTIFIED
# Healthy_School_Certification_Description     This school has not achieved Healthy School Ce...
# Creative_School_Certification                                                              NaN
# Creative_School_Certification_Description    This school has an arts designation of Incompl...
# NWEA_Reading_Growth_Grade_3_Pct                                                            NaN
# NWEA_Reading_Growth_Grade_3_Lbl                                                            NaN
# NWEA_Reading_Growth_Grade_4_Pct                                                            NaN
# NWEA_Reading_Growth_Grade_4_Lbl                                                            NaN
# NWEA_Reading_Growth_Grade_5_Pct                                                            NaN
# NWEA_Reading_Growth_Grade_5_Lbl                                                            NaN
# NWEA_Reading_Growth_Grade_6_Pct                                                            NaN
# NWEA_Reading_Growth_Grade_6_Lbl                                                            NaN
# NWEA_Reading_Growth_Grade_7_Pct                                                            NaN
# NWEA_Reading_Growth_Grade_7_Lbl                                                            NaN
# NWEA_Reading_Growth_Grade_8_Pct                                                            NaN
# NWEA_Reading_Growth_Grade_8_Lbl                                                            NaN
# NWEA_Math_Growth_Grade_3_Pct                                                               NaN
# NWEA_Math_Growth_Grade_3_Lbl                                                               NaN
# NWEA_Math_Growth_Grade_4_Pct                                                               NaN
# NWEA_Math_Growth_Grade_4_Lbl                                                               NaN
# NWEA_Math_Growth_Grade_5_Pct                                                               NaN
# NWEA_Math_Growth_Grade_5_Lbl                                                               NaN
# NWEA_Math_Growth_Grade_6_Pct                                                               NaN
# NWEA_Math_Growth_Grade_6_Lbl                                                               NaN
# NWEA_Math_Growth_Grade_7_Pct                                                               NaN
# NWEA_Math_Growth_Grade_7_Lbl                                                               NaN
# NWEA_Math_Growth_Grade_8_Pct                                                               NaN
# NWEA_Math_Growth_Grade_8_Lbl                                                               NaN
# NWEA_Reading_Attainment_Grade_2_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_2_Lbl                                                        NaN
# NWEA_Reading_Attainment_Grade_3_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_3_Lbl                                                        NaN
# NWEA_Reading_Attainment_Grade_4_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_4_Lbl                                                        NaN
# NWEA_Reading_Attainment_Grade_5_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_5_Lbl                                                        NaN
# NWEA_Reading_Attainment_Grade_6_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_6_Lbl                                                        NaN
# NWEA_Reading_Attainment_Grade_7_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_7_Lbl                                                        NaN
# NWEA_Reading_Attainment_Grade_8_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_8_Lbl                                                        NaN
# NWEA_Math_Attainment_Grade_2_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_2_Lbl                                                           NaN
# NWEA_Math_Attainment_Grade_3_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_3_Lbl                                                           NaN
# NWEA_Math_Attainment_Grade_4_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_4_Lbl                                                           NaN
# NWEA_Math_Attainment_Grade_5_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_5_Lbl                                                           NaN
# NWEA_Math_Attainment_Grade_6_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_6_Lbl                                                           NaN
# NWEA_Math_Attainment_Grade_7_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_7_Lbl                                                           NaN
# NWEA_Math_Attainment_Grade_8_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_8_Lbl                                                           NaN
# School_Survey_Involved_Families                                                      VERY WEAK
# School_Survey_Supportive_Environment                                                   NEUTRAL
# School_Survey_Ambitious_Instruction                                                    NEUTRAL
# School_Survey_Effective_Leaders                                                        NEUTRAL
# School_Survey_Collaborative_Teachers                                                   NEUTRAL
# School_Survey_Safety                                                                      WEAK
# Suspensions_Per_100_Students_Year_1_Pct                                                    NaN
# Suspensions_Per_100_Students_Year_2_Pct                                                    NaN
# Suspensions_Per_100_Students_Avg_Pct                                                      20.8
# Misconducts_To_Suspensions_Year_1_Pct                                                      NaN
# Misconducts_To_Suspensions_Year_2_Pct                                                      NaN
# Misconducts_To_Suspensions_Avg_Pct                                                        18.3
# Average_Length_Suspension_Year_1_Pct                                                       NaN
# Average_Length_Suspension_Year_2_Pct                                                       NaN
# Average_Length_Suspension_Avg_Pct                                                     2.5 days
# Behavior_Discipline_Year_1                                                                2014
# Behavior_Discipline_Year_2                                                                2015
# School_Survey_School_Community                                                             NaN
# School_Survey_Parent_Teacher_Partnership                                                   NaN
# School_Survey_Quality_Of_Facilities                                                        NaN
# Student_Attendance_Year_1_Pct                                                               78
# Student_Attendance_Year_2_Pct                                                             73.3
# Student_Attendance_Avg_Pct                                                                88.8
# Teacher_Attendance_Year_1_Pct                                                              NaN
# Teacher_Attendance_Year_2_Pct                                                              NaN
# Teacher_Attendance_Avg_Pct                                                                 NaN
# One_Year_Dropout_Rate_Year_1_Pct                                                          31.3
# One_Year_Dropout_Rate_Year_2_Pct                                                          39.4
# One_Year_Dropout_Rate_Avg_Pct                                                              7.9
# Other_Metrics_Year_1                                                                      2014
# Other_Metrics_Year_2                                                                      2015
# Growth_ACT_Grade_11_Pct                                                                    NaN
# Growth_ACT_Grade_11_Lbl                                                                    NaN
# Attainment_ACT_Grade_11_Pct                                                                  4
# Attainment_ACT_Grade_11_Lbl                                                                4th
# Freshmen_On_Track_School_Pct_Year_2                                                        NaN
# Freshmen_On_Track_CPS_Pct_Year_2                                                          84.1
# Freshmen_On_Track_School_Pct_Year_1                                                        NaN
# Freshmen_On_Track_CPS_Pct_Year_1                                                          82.6
# College_Enrollment_School_Pct_Year_2                                                       9.8
# College_Enrollment_CPS_Pct_Year_2                                                         58.7
# College_Enrollment_School_Pct_Year_1                                                      14.6
# College_Enrollment_CPS_Pct_Year_1                                                         58.1
# College_Persistence_School_Pct_Year_2                                                     33.3
# College_Persistence_CPS_Pct_Year_2                                                          70
# College_Persistence_School_Pct_Year_1                                                      NaN
# College_Persistence_CPS_Pct_Year_1                                                        70.1
# Progress_Toward_Graduation_Year_1                                                         2014
# Progress_Toward_Graduation_Year_2                                                         2015
# State_School_Report_Card_URL                 http://iirc.niu.edu/School.aspx?schoolid=15016...
# Mobility_Rate_Pct                                                                          NaN
# Chronic_Truancy_Pct                                                                        NaN
# Empty_Progress_Report_Message                A School Progress Report customized for CPS Op...
# School_Survey_Rating_Description             This school is “Partially Organized for Improv...
# Supportive_School_Award                                                              NOT RATED
# Supportive_School_Award_Desc                 This school is in the process of being reviewe...
# Parent_Survey_Results_Year                                                                2015
# School_Latitude                                                                        41.8547
# School_Longitude                                                                      -87.6954
# Location                                     2001 S CALIFORNIA AVE\r\nChicago, Illinois 606...

# %% [markdown]
# My overall goal is to retain as much of the data as possible, since the Random Forest models will be able to key into key variables even if purely extraneous data is retained in the input datasets.  With that said, we can eliminate information regarding the street address, website, phone number, etc. for a school.

# %%
cols_to_drop = ['Address','Short_Name','Fax', 'City','State','Phone','CPS_School_Profile','Website', 'Empty_Progress_Report_Message', 'State_School_Report_Card_URL', 'Location', 'Zip']
df_201516.drop(cols_to_drop, axis = 1, inplace = True)

# %%
display_all(df_201516.tail().T)
# Out:
#                                                                                            665  \
# School_ID                                                                               610173
# Long_Name                                                     Jesse Sherwood Elementary School
# School_Type                                                                       Neighborhood
# Primary_Category                                                                            ES
# Progress_Report_Year                                                                      2015
# Blue_Ribbon_Award_Year                                                                     NaN
# Excelerate_Award_Gold_Year                                                                 NaN
# Spot_Light_Award_Year                                                                      NaN
# Improvement_Award_Year                                                                     NaN
# Excellence_Award_Year                                                                      NaN
# Student_Growth_Rating                                                        FAR ABOVE AVERAGE
# Student_Growth_Description                   Student Growth measures the change in standard...
# Growth_Reading_Grades_Tested_Pct_ES                                                         99
# Growth_Reading_Grades_Tested_Label_ES                                                     99th
# Growth_Math_Grades_Tested_Pct_ES                                                            99
# Growth_Math_Grades_Tested_Label_ES                                                        99th
# Student_Attainment_Rating                                                    FAR ABOVE AVERAGE
# Student_Attainment_Description               Student Attainment measures how well the schoo...
# Attainment_Reading_Pct_ES                                                                   96
# Attainment_Reading_Lbl_ES                                                                 96th
# Attainment_Math_Pct_ES                                                                      93
# Attainment_Math_Lbl_ES                                                                    93rd
# Culture_Climate_Rating                                                          WELL ORGANIZED
# Culture_Climate_Description                  Results are based on student and teacher respo...
# School_Survey_Student_Response_Rate_Pct                                                   99.9
# School_Survey_Student_Response_Rate_Avg_Pct                                               81.2
# School_Survey_Teacher_Response_Rate_Pct                                                   95.8
# School_Survey_Teacher_Response_Rate_Avg_Pct                                               80.7
# Healthy_School_Certification                                                     NOT CERTIFIED
# Healthy_School_Certification_Description     This school has not achieved Healthy School Ce...
# Creative_School_Certification                                                        EXCELLING
# Creative_School_Certification_Description    This school is Excelling in the arts. It meets...
# NWEA_Reading_Growth_Grade_3_Pct                                                             99
# NWEA_Reading_Growth_Grade_3_Lbl                                                           99th
# NWEA_Reading_Growth_Grade_4_Pct                                                             99
# NWEA_Reading_Growth_Grade_4_Lbl                                                           99th
# NWEA_Reading_Growth_Grade_5_Pct                                                             99
# NWEA_Reading_Growth_Grade_5_Lbl                                                           99th
# NWEA_Reading_Growth_Grade_6_Pct                                                             99
# NWEA_Reading_Growth_Grade_6_Lbl                                                           99th
# NWEA_Reading_Growth_Grade_7_Pct                                                             99
# NWEA_Reading_Growth_Grade_7_Lbl                                                           99th
# NWEA_Reading_Growth_Grade_8_Pct                                                             79
# NWEA_Reading_Growth_Grade_8_Lbl                                                           79th
# NWEA_Math_Growth_Grade_3_Pct                                                                99
# NWEA_Math_Growth_Grade_3_Lbl                                                              99th
# NWEA_Math_Growth_Grade_4_Pct                                                                99
# NWEA_Math_Growth_Grade_4_Lbl                                                              99th
# NWEA_Math_Growth_Grade_5_Pct                                                                99
# NWEA_Math_Growth_Grade_5_Lbl                                                              99th
# NWEA_Math_Growth_Grade_6_Pct                                                                99
# NWEA_Math_Growth_Grade_6_Lbl                                                              99th
# NWEA_Math_Growth_Grade_7_Pct                                                                99
# NWEA_Math_Growth_Grade_7_Lbl                                                              99th
# NWEA_Math_Growth_Grade_8_Pct                                                                99
# NWEA_Math_Growth_Grade_8_Lbl                                                              99th
# NWEA_Reading_Attainment_Grade_2_Pct                                                         95
# NWEA_Reading_Attainment_Grade_2_Lbl                                                       95th
# NWEA_Reading_Attainment_Grade_3_Pct                                                         86
# NWEA_Reading_Attainment_Grade_3_Lbl                                                       86th
# NWEA_Reading_Attainment_Grade_4_Pct                                                         99
# NWEA_Reading_Attainment_Grade_4_Lbl                                                       99th
# NWEA_Reading_Attainment_Grade_5_Pct                                                         97
# NWEA_Reading_Attainment_Grade_5_Lbl                                                       97th
# NWEA_Reading_Attainment_Grade_6_Pct                                                         88
# NWEA_Reading_Attainment_Grade_6_Lbl                                                       88th
# NWEA_Reading_Attainment_Grade_7_Pct                                                         73
# NWEA_Reading_Attainment_Grade_7_Lbl                                                       73rd
# NWEA_Reading_Attainment_Grade_8_Pct                                                         58
# NWEA_Reading_Attainment_Grade_8_Lbl                                                       58th
# NWEA_Math_Attainment_Grade_2_Pct                                                            99
# NWEA_Math_Attainment_Grade_2_Lbl                                                          99th
# NWEA_Math_Attainment_Grade_3_Pct                                                            82
# NWEA_Math_Attainment_Grade_3_Lbl                                                          82nd
# NWEA_Math_Attainment_Grade_4_Pct                                                            99
# NWEA_Math_Attainment_Grade_4_Lbl                                                          99th
# NWEA_Math_Attainment_Grade_5_Pct                                                            75
# NWEA_Math_Attainment_Grade_5_Lbl                                                          75th
# NWEA_Math_Attainment_Grade_6_Pct                                                            82
# NWEA_Math_Attainment_Grade_6_Lbl                                                          82nd
# NWEA_Math_Attainment_Grade_7_Pct                                                            88
# NWEA_Math_Attainment_Grade_7_Lbl                                                          88th
# NWEA_Math_Attainment_Grade_8_Pct                                                            74
# NWEA_Math_Attainment_Grade_8_Lbl                                                          74th
# School_Survey_Involved_Families                                                        NEUTRAL
# School_Survey_Supportive_Environment                                               VERY STRONG
# School_Survey_Ambitious_Instruction                                                VERY STRONG
# School_Survey_Effective_Leaders                                                         STRONG
# School_Survey_Collaborative_Teachers                                                    STRONG
# School_Survey_Safety                                                                    STRONG
# Suspensions_Per_100_Students_Year_1_Pct                                                    5.8
# Suspensions_Per_100_Students_Year_2_Pct                                                    1.7
# Suspensions_Per_100_Students_Avg_Pct                                                       3.8
# Misconducts_To_Suspensions_Year_1_Pct                                                     62.2
# Misconducts_To_Suspensions_Year_2_Pct                                                     18.2
# Misconducts_To_Suspensions_Avg_Pct                                                        18.4
# Average_Length_Suspension_Year_1_Pct                                                  2.7 days
# Average_Length_Suspension_Year_2_Pct                                                  2.7 days
# Average_Length_Suspension_Avg_Pct                                                     2.1 days
# Behavior_Discipline_Year_1                                                                2014
# Behavior_Discipline_Year_2                                                                2015
# School_Survey_School_Community                                                          Strong
# School_Survey_Parent_Teacher_Partnership                                               Neutral
# School_Survey_Quality_Of_Facilities                                                     Strong
# Student_Attendance_Year_1_Pct                                                               95
# Student_Attendance_Year_2_Pct                                                             95.9
# Student_Attendance_Avg_Pct                                                                95.1
# Teacher_Attendance_Year_1_Pct                                                             97.6
# Teacher_Attendance_Year_2_Pct                                                             96.3
# Teacher_Attendance_Avg_Pct                                                                  95
# One_Year_Dropout_Rate_Year_1_Pct                                                           NaN
# One_Year_Dropout_Rate_Year_2_Pct                                                           NaN
# One_Year_Dropout_Rate_Avg_Pct                                                              7.9
# Other_Metrics_Year_1                                                                      2014
# Other_Metrics_Year_2                                                                      2015
# Growth_ACT_Grade_11_Pct                                                                    NaN
# Growth_ACT_Grade_11_Lbl                                                                    NaN
# Attainment_ACT_Grade_11_Pct                                                                NaN
# Attainment_ACT_Grade_11_Lbl                                                                NaN
# Freshmen_On_Track_School_Pct_Year_2                                                        NaN
# Freshmen_On_Track_CPS_Pct_Year_2                                                          84.1
# Freshmen_On_Track_School_Pct_Year_1                                                        NaN
# Freshmen_On_Track_CPS_Pct_Year_1                                                          82.6
# College_Enrollment_School_Pct_Year_2                                                       NaN
# College_Enrollment_CPS_Pct_Year_2                                                         58.7
# College_Enrollment_School_Pct_Year_1                                                       NaN
# College_Enrollment_CPS_Pct_Year_1                                                         58.1
# College_Persistence_School_Pct_Year_2                                                      NaN
# College_Persistence_CPS_Pct_Year_2                                                          70
# College_Persistence_School_Pct_Year_1                                                      NaN
# College_Persistence_CPS_Pct_Year_1                                                        70.1
# Progress_Toward_Graduation_Year_1                                                         2014
# Progress_Toward_Graduation_Year_2                                                         2015
# Mobility_Rate_Pct                                                                         32.3
# Chronic_Truancy_Pct                                                                        NaN
# School_Survey_Rating_Description             This school is “Well-Organized for Improvement...
# Supportive_School_Award                                                              NOT RATED
# Supportive_School_Award_Desc                 This school is in the process of being reviewe...
# Parent_Survey_Results_Year                                                                2015
# School_Latitude                                                                        41.7908
# School_Longitude                                                                      -87.6323
#
#                                                                                            666  \
# School_ID                                                                               610115
# Long_Name                                                         Park Manor Elementary School
# School_Type                                                                       Neighborhood
# Primary_Category                                                                            ES
# Progress_Report_Year                                                                      2015
# Blue_Ribbon_Award_Year                                                                     NaN
# Excelerate_Award_Gold_Year                                                                 NaN
# Spot_Light_Award_Year                                                                      NaN
# Improvement_Award_Year                                                                    2012
# Excellence_Award_Year                                                                      NaN
# Student_Growth_Rating                                                                  AVERAGE
# Student_Growth_Description                   Student Growth measures the change in standard...
# Growth_Reading_Grades_Tested_Pct_ES                                                         43
# Growth_Reading_Grades_Tested_Label_ES                                                     43rd
# Growth_Math_Grades_Tested_Pct_ES                                                            31
# Growth_Math_Grades_Tested_Label_ES                                                        31st
# Student_Attainment_Rating                                                        BELOW AVERAGE
# Student_Attainment_Description               Student Attainment measures how well the schoo...
# Attainment_Reading_Pct_ES                                                                   24
# Attainment_Reading_Lbl_ES                                                                 24th
# Attainment_Math_Pct_ES                                                                      25
# Attainment_Math_Lbl_ES                                                                    25th
# Culture_Climate_Rating                                                          WELL ORGANIZED
# Culture_Climate_Description                  Results are based on student and teacher respo...
# School_Survey_Student_Response_Rate_Pct                                                   87.7
# School_Survey_Student_Response_Rate_Avg_Pct                                               81.2
# School_Survey_Teacher_Response_Rate_Pct                                                   73.7
# School_Survey_Teacher_Response_Rate_Avg_Pct                                               80.7
# Healthy_School_Certification                                                     NOT CERTIFIED
# Healthy_School_Certification_Description     This school has not achieved Healthy School Ce...
# Creative_School_Certification                                                       DEVELOPING
# Creative_School_Certification_Description    This school is Developing in the arts. It occa...
# NWEA_Reading_Growth_Grade_3_Pct                                                             66
# NWEA_Reading_Growth_Grade_3_Lbl                                                           66th
# NWEA_Reading_Growth_Grade_4_Pct                                                             74
# NWEA_Reading_Growth_Grade_4_Lbl                                                           74th
# NWEA_Reading_Growth_Grade_5_Pct                                                              3
# NWEA_Reading_Growth_Grade_5_Lbl                                                            3rd
# NWEA_Reading_Growth_Grade_6_Pct                                                             57
# NWEA_Reading_Growth_Grade_6_Lbl                                                           57th
# NWEA_Reading_Growth_Grade_7_Pct                                                             71
# NWEA_Reading_Growth_Grade_7_Lbl                                                           71st
# NWEA_Reading_Growth_Grade_8_Pct                                                             16
# NWEA_Reading_Growth_Grade_8_Lbl                                                           16th
# NWEA_Math_Growth_Grade_3_Pct                                                                 1
# NWEA_Math_Growth_Grade_3_Lbl                                                               1st
# NWEA_Math_Growth_Grade_4_Pct                                                                 2
# NWEA_Math_Growth_Grade_4_Lbl                                                               2nd
# NWEA_Math_Growth_Grade_5_Pct                                                                30
# NWEA_Math_Growth_Grade_5_Lbl                                                              30th
# NWEA_Math_Growth_Grade_6_Pct                                                                81
# NWEA_Math_Growth_Grade_6_Lbl                                                              81st
# NWEA_Math_Growth_Grade_7_Pct                                                                95
# NWEA_Math_Growth_Grade_7_Lbl                                                              95th
# NWEA_Math_Growth_Grade_8_Pct                                                                60
# NWEA_Math_Growth_Grade_8_Lbl                                                              60th
# NWEA_Reading_Attainment_Grade_2_Pct                                                         40
# NWEA_Reading_Attainment_Grade_2_Lbl                                                       40th
# NWEA_Reading_Attainment_Grade_3_Pct                                                         25
# NWEA_Reading_Attainment_Grade_3_Lbl                                                       25th
# NWEA_Reading_Attainment_Grade_4_Pct                                                         23
# NWEA_Reading_Attainment_Grade_4_Lbl                                                       23rd
# NWEA_Reading_Attainment_Grade_5_Pct                                                          7
# NWEA_Reading_Attainment_Grade_5_Lbl                                                        7th
# NWEA_Reading_Attainment_Grade_6_Pct                                                         30
# NWEA_Reading_Attainment_Grade_6_Lbl                                                       30th
# NWEA_Reading_Attainment_Grade_7_Pct                                                         58
# NWEA_Reading_Attainment_Grade_7_Lbl                                                       58th
# NWEA_Reading_Attainment_Grade_8_Pct                                                         19
# NWEA_Reading_Attainment_Grade_8_Lbl                                                       19th
# NWEA_Math_Attainment_Grade_2_Pct                                                            36
# NWEA_Math_Attainment_Grade_2_Lbl                                                          36th
# NWEA_Math_Attainment_Grade_3_Pct                                                             4
# NWEA_Math_Attainment_Grade_3_Lbl                                                           4th
# NWEA_Math_Attainment_Grade_4_Pct                                                             6
# NWEA_Math_Attainment_Grade_4_Lbl                                                           6th
# NWEA_Math_Attainment_Grade_5_Pct                                                            16
# NWEA_Math_Attainment_Grade_5_Lbl                                                          16th
# NWEA_Math_Attainment_Grade_6_Pct                                                            34
# NWEA_Math_Attainment_Grade_6_Lbl                                                          34th
# NWEA_Math_Attainment_Grade_7_Pct                                                            67
# NWEA_Math_Attainment_Grade_7_Lbl                                                          67th
# NWEA_Math_Attainment_Grade_8_Pct                                                            66
# NWEA_Math_Attainment_Grade_8_Lbl                                                          66th
# School_Survey_Involved_Families                                                         STRONG
# School_Survey_Supportive_Environment                                                    STRONG
# School_Survey_Ambitious_Instruction                                                VERY STRONG
# School_Survey_Effective_Leaders                                                         STRONG
# School_Survey_Collaborative_Teachers                                               VERY STRONG
# School_Survey_Safety                                                                      WEAK
# Suspensions_Per_100_Students_Year_1_Pct                                                    2.9
# Suspensions_Per_100_Students_Year_2_Pct                                                    3.7
# Suspensions_Per_100_Students_Avg_Pct                                                       3.8
# Misconducts_To_Suspensions_Year_1_Pct                                                     47.6
# Misconducts_To_Suspensions_Year_2_Pct                                                     48.3
# Misconducts_To_Suspensions_Avg_Pct                                                        18.4
# Average_Length_Suspension_Year_1_Pct                                                  3.0 days
# Average_Length_Suspension_Year_2_Pct                                                  3.1 days
# Average_Length_Suspension_Avg_Pct                                                     2.1 days
# Behavior_Discipline_Year_1                                                                2014
# Behavior_Discipline_Year_2                                                                2015
# School_Survey_School_Community                                                             NaN
# School_Survey_Parent_Teacher_Partnership                                                   NaN
# School_Survey_Quality_Of_Facilities                                                        NaN
# Student_Attendance_Year_1_Pct                                                               96
# Student_Attendance_Year_2_Pct                                                             96.1
# Student_Attendance_Avg_Pct                                                                95.1
# Teacher_Attendance_Year_1_Pct                                                             95.5
# Teacher_Attendance_Year_2_Pct                                                             96.1
# Teacher_Attendance_Avg_Pct                                                                  95
# One_Year_Dropout_Rate_Year_1_Pct                                                           NaN
# One_Year_Dropout_Rate_Year_2_Pct                                                           NaN
# One_Year_Dropout_Rate_Avg_Pct                                                              7.9
# Other_Metrics_Year_1                                                                      2014
# Other_Metrics_Year_2                                                                      2015
# Growth_ACT_Grade_11_Pct                                                                    NaN
# Growth_ACT_Grade_11_Lbl                                                                    NaN
# Attainment_ACT_Grade_11_Pct                                                                NaN
# Attainment_ACT_Grade_11_Lbl                                                                NaN
# Freshmen_On_Track_School_Pct_Year_2                                                        NaN
# Freshmen_On_Track_CPS_Pct_Year_2                                                          84.1
# Freshmen_On_Track_School_Pct_Year_1                                                        NaN
# Freshmen_On_Track_CPS_Pct_Year_1                                                          82.6
# College_Enrollment_School_Pct_Year_2                                                       NaN
# College_Enrollment_CPS_Pct_Year_2                                                         58.7
# College_Enrollment_School_Pct_Year_1                                                       NaN
# College_Enrollment_CPS_Pct_Year_1                                                         58.1
# College_Persistence_School_Pct_Year_2                                                      NaN
# College_Persistence_CPS_Pct_Year_2                                                          70
# College_Persistence_School_Pct_Year_1                                                      NaN
# College_Persistence_CPS_Pct_Year_1                                                        70.1
# Progress_Toward_Graduation_Year_1                                                         2014
# Progress_Toward_Graduation_Year_2                                                         2015
# Mobility_Rate_Pct                                                                         41.2
# Chronic_Truancy_Pct                                                                        NaN
# School_Survey_Rating_Description             This school is “Well-Organized for Improvement...
# Supportive_School_Award                                                              NOT RATED
# Supportive_School_Award_Desc                 This school is in the process of being reviewe...
# Parent_Survey_Results_Year                                                                2015
# School_Latitude                                                                        41.7665
# School_Longitude                                                                      -87.6115
#
#                                                                                            667  \
# School_ID                                                                               609996
# Long_Name                                                   Charles N Holden Elementary School
# School_Type                                                                       Neighborhood
# Primary_Category                                                                            ES
# Progress_Report_Year                                                                      2015
# Blue_Ribbon_Award_Year                                                                     NaN
# Excelerate_Award_Gold_Year                                                                2015
# Spot_Light_Award_Year                                                                      NaN
# Improvement_Award_Year                                                                     NaN
# Excellence_Award_Year                                                                      NaN
# Student_Growth_Rating                                                        FAR ABOVE AVERAGE
# Student_Growth_Description                   Student Growth measures the change in standard...
# Growth_Reading_Grades_Tested_Pct_ES                                                         71
# Growth_Reading_Grades_Tested_Label_ES                                                     71st
# Growth_Math_Grades_Tested_Pct_ES                                                            93
# Growth_Math_Grades_Tested_Label_ES                                                        93rd
# Student_Attainment_Rating                                                        ABOVE AVERAGE
# Student_Attainment_Description               Student Attainment measures how well the schoo...
# Attainment_Reading_Pct_ES                                                                   58
# Attainment_Reading_Lbl_ES                                                                 58th
# Attainment_Math_Pct_ES                                                                      81
# Attainment_Math_Lbl_ES                                                                    81st
# Culture_Climate_Rating                                                          WELL ORGANIZED
# Culture_Climate_Description                  Results are based on student and teacher respo...
# School_Survey_Student_Response_Rate_Pct                                                   88.6
# School_Survey_Student_Response_Rate_Avg_Pct                                               81.2
# School_Survey_Teacher_Response_Rate_Pct                                                   90.3
# School_Survey_Teacher_Response_Rate_Avg_Pct                                               80.7
# Healthy_School_Certification                                                     NOT CERTIFIED
# Healthy_School_Certification_Description     This school has not achieved Healthy School Ce...
# Creative_School_Certification                                                        EXCELLING
# Creative_School_Certification_Description    This school is Excelling in the arts. It meets...
# NWEA_Reading_Growth_Grade_3_Pct                                                             28
# NWEA_Reading_Growth_Grade_3_Lbl                                                           28th
# NWEA_Reading_Growth_Grade_4_Pct                                                             38
# NWEA_Reading_Growth_Grade_4_Lbl                                                           38th
# NWEA_Reading_Growth_Grade_5_Pct                                                             58
# NWEA_Reading_Growth_Grade_5_Lbl                                                           58th
# NWEA_Reading_Growth_Grade_6_Pct                                                             95
# NWEA_Reading_Growth_Grade_6_Lbl                                                           95th
# NWEA_Reading_Growth_Grade_7_Pct                                                             90
# NWEA_Reading_Growth_Grade_7_Lbl                                                           90th
# NWEA_Reading_Growth_Grade_8_Pct                                                             62
# NWEA_Reading_Growth_Grade_8_Lbl                                                           62nd
# NWEA_Math_Growth_Grade_3_Pct                                                                20
# NWEA_Math_Growth_Grade_3_Lbl                                                              20th
# NWEA_Math_Growth_Grade_4_Pct                                                                99
# NWEA_Math_Growth_Grade_4_Lbl                                                              99th
# NWEA_Math_Growth_Grade_5_Pct                                                                42
# NWEA_Math_Growth_Grade_5_Lbl                                                              42nd
# NWEA_Math_Growth_Grade_6_Pct                                                                83
# NWEA_Math_Growth_Grade_6_Lbl                                                              83rd
# NWEA_Math_Growth_Grade_7_Pct                                                                99
# NWEA_Math_Growth_Grade_7_Lbl                                                              99th
# NWEA_Math_Growth_Grade_8_Pct                                                                99
# NWEA_Math_Growth_Grade_8_Lbl                                                              99th
# NWEA_Reading_Attainment_Grade_2_Pct                                                         38
# NWEA_Reading_Attainment_Grade_2_Lbl                                                       38th
# NWEA_Reading_Attainment_Grade_3_Pct                                                         55
# NWEA_Reading_Attainment_Grade_3_Lbl                                                       55th
# NWEA_Reading_Attainment_Grade_4_Pct                                                         51
# NWEA_Reading_Attainment_Grade_4_Lbl                                                       51st
# NWEA_Reading_Attainment_Grade_5_Pct                                                         50
# NWEA_Reading_Attainment_Grade_5_Lbl                                                       50th
# NWEA_Reading_Attainment_Grade_6_Pct                                                         60
# NWEA_Reading_Attainment_Grade_6_Lbl                                                       60th
# NWEA_Reading_Attainment_Grade_7_Pct                                                         73
# NWEA_Reading_Attainment_Grade_7_Lbl                                                       73rd
# NWEA_Reading_Attainment_Grade_8_Pct                                                         66
# NWEA_Reading_Attainment_Grade_8_Lbl                                                       66th
# NWEA_Math_Attainment_Grade_2_Pct                                                            53
# NWEA_Math_Attainment_Grade_2_Lbl                                                          53rd
# NWEA_Math_Attainment_Grade_3_Pct                                                            43
# NWEA_Math_Attainment_Grade_3_Lbl                                                          43rd
# NWEA_Math_Attainment_Grade_4_Pct                                                            75
# NWEA_Math_Attainment_Grade_4_Lbl                                                          75th
# NWEA_Math_Attainment_Grade_5_Pct                                                            51
# NWEA_Math_Attainment_Grade_5_Lbl                                                          51st
# NWEA_Math_Attainment_Grade_6_Pct                                                            83
# NWEA_Math_Attainment_Grade_6_Lbl                                                          83rd
# NWEA_Math_Attainment_Grade_7_Pct                                                            97
# NWEA_Math_Attainment_Grade_7_Lbl                                                          97th
# NWEA_Math_Attainment_Grade_8_Pct                                                            97
# NWEA_Math_Attainment_Grade_8_Lbl                                                          97th
# School_Survey_Involved_Families                                                         STRONG
# School_Survey_Supportive_Environment                                                    STRONG
# School_Survey_Ambitious_Instruction                                                     STRONG
# School_Survey_Effective_Leaders                                                        NEUTRAL
# School_Survey_Collaborative_Teachers                                                    STRONG
# School_Survey_Safety                                                                   NEUTRAL
# Suspensions_Per_100_Students_Year_1_Pct                                                    4.4
# Suspensions_Per_100_Students_Year_2_Pct                                                      3
# Suspensions_Per_100_Students_Avg_Pct                                                       3.8
# Misconducts_To_Suspensions_Year_1_Pct                                                     61.5
# Misconducts_To_Suspensions_Year_2_Pct                                                     28.1
# Misconducts_To_Suspensions_Avg_Pct                                                        18.4
# Average_Length_Suspension_Year_1_Pct                                                  2.5 days
# Average_Length_Suspension_Year_2_Pct                                                  1.9 days
# Average_Length_Suspension_Avg_Pct                                                     2.1 days
# Behavior_Discipline_Year_1                                                                2014
# Behavior_Discipline_Year_2                                                                2015
# School_Survey_School_Community                                                         Neutral
# School_Survey_Parent_Teacher_Partnership                                               Neutral
# School_Survey_Quality_Of_Facilities                                                    Neutral
# Student_Attendance_Year_1_Pct                                                             94.5
# Student_Attendance_Year_2_Pct                                                             94.8
# Student_Attendance_Avg_Pct                                                                95.1
# Teacher_Attendance_Year_1_Pct                                                             95.5
# Teacher_Attendance_Year_2_Pct                                                             94.3
# Teacher_Attendance_Avg_Pct                                                                  95
# One_Year_Dropout_Rate_Year_1_Pct                                                           NaN
# One_Year_Dropout_Rate_Year_2_Pct                                                           NaN
# One_Year_Dropout_Rate_Avg_Pct                                                              7.9
# Other_Metrics_Year_1                                                                      2014
# Other_Metrics_Year_2                                                                      2015
# Growth_ACT_Grade_11_Pct                                                                    NaN
# Growth_ACT_Grade_11_Lbl                                                                    NaN
# Attainment_ACT_Grade_11_Pct                                                                NaN
# Attainment_ACT_Grade_11_Lbl                                                                NaN
# Freshmen_On_Track_School_Pct_Year_2                                                        NaN
# Freshmen_On_Track_CPS_Pct_Year_2                                                          84.1
# Freshmen_On_Track_School_Pct_Year_1                                                        NaN
# Freshmen_On_Track_CPS_Pct_Year_1                                                          82.6
# College_Enrollment_School_Pct_Year_2                                                       NaN
# College_Enrollment_CPS_Pct_Year_2                                                         58.7
# College_Enrollment_School_Pct_Year_1                                                       NaN
# College_Enrollment_CPS_Pct_Year_1                                                         58.1
# College_Persistence_School_Pct_Year_2                                                      NaN
# College_Persistence_CPS_Pct_Year_2                                                          70
# College_Persistence_School_Pct_Year_1                                                      NaN
# College_Persistence_CPS_Pct_Year_1                                                        70.1
# Progress_Toward_Graduation_Year_1                                                         2014
# Progress_Toward_Graduation_Year_2                                                         2015
# Mobility_Rate_Pct                                                                         14.2
# Chronic_Truancy_Pct                                                                        NaN
# School_Survey_Rating_Description             This school is “Well-Organized for Improvement...
# Supportive_School_Award                                                              NOT RATED
# Supportive_School_Award_Desc                 This school is in the process of being reviewe...
# Parent_Survey_Results_Year                                                                2015
# School_Latitude                                                                         41.838
# School_Longitude                                                                      -87.6538
#
#                                                                                            668  \
# School_ID                                                                               609815
# Long_Name                                           Edward A Bouchet Math & Science Academy ES
# School_Type                                                                       Neighborhood
# Primary_Category                                                                            ES
# Progress_Report_Year                                                                      2015
# Blue_Ribbon_Award_Year                                                                     NaN
# Excelerate_Award_Gold_Year                                                                 NaN
# Spot_Light_Award_Year                                                                      NaN
# Improvement_Award_Year                                                                     NaN
# Excellence_Award_Year                                                                      NaN
# Student_Growth_Rating                                                            ABOVE AVERAGE
# Student_Growth_Description                   Student Growth measures the change in standard...
# Growth_Reading_Grades_Tested_Pct_ES                                                         95
# Growth_Reading_Grades_Tested_Label_ES                                                     95th
# Growth_Math_Grades_Tested_Pct_ES                                                            67
# Growth_Math_Grades_Tested_Label_ES                                                        67th
# Student_Attainment_Rating                                                              AVERAGE
# Student_Attainment_Description               Student Attainment measures how well the schoo...
# Attainment_Reading_Pct_ES                                                                   52
# Attainment_Reading_Lbl_ES                                                                 52nd
# Attainment_Math_Pct_ES                                                                      39
# Attainment_Math_Lbl_ES                                                                    39th
# Culture_Climate_Rating                                                          WELL ORGANIZED
# Culture_Climate_Description                  Results are based on student and teacher respo...
# School_Survey_Student_Response_Rate_Pct                                                   99.9
# School_Survey_Student_Response_Rate_Avg_Pct                                               81.2
# School_Survey_Teacher_Response_Rate_Pct                                                   99.9
# School_Survey_Teacher_Response_Rate_Avg_Pct                                               80.7
# Healthy_School_Certification                                         HEALTHY SCHOOLS CERTIFIED
# Healthy_School_Certification_Description     This school has achieved Healthy School Certif...
# Creative_School_Certification                                                        EXCELLING
# Creative_School_Certification_Description    This school is Excelling in the arts. It meets...
# NWEA_Reading_Growth_Grade_3_Pct                                                             81
# NWEA_Reading_Growth_Grade_3_Lbl                                                           81st
# NWEA_Reading_Growth_Grade_4_Pct                                                             99
# NWEA_Reading_Growth_Grade_4_Lbl                                                           99th
# NWEA_Reading_Growth_Grade_5_Pct                                                             58
# NWEA_Reading_Growth_Grade_5_Lbl                                                           58th
# NWEA_Reading_Growth_Grade_6_Pct                                                             78
# NWEA_Reading_Growth_Grade_6_Lbl                                                           78th
# NWEA_Reading_Growth_Grade_7_Pct                                                             92
# NWEA_Reading_Growth_Grade_7_Lbl                                                           92nd
# NWEA_Reading_Growth_Grade_8_Pct                                                             93
# NWEA_Reading_Growth_Grade_8_Lbl                                                           93rd
# NWEA_Math_Growth_Grade_3_Pct                                                                64
# NWEA_Math_Growth_Grade_3_Lbl                                                              64th
# NWEA_Math_Growth_Grade_4_Pct                                                                99
# NWEA_Math_Growth_Grade_4_Lbl                                                              99th
# NWEA_Math_Growth_Grade_5_Pct                                                                60
# NWEA_Math_Growth_Grade_5_Lbl                                                              60th
# NWEA_Math_Growth_Grade_6_Pct                                                                44
# NWEA_Math_Growth_Grade_6_Lbl                                                              44th
# NWEA_Math_Growth_Grade_7_Pct                                                                22
# NWEA_Math_Growth_Grade_7_Lbl                                                              22nd
# NWEA_Math_Growth_Grade_8_Pct                                                                60
# NWEA_Math_Growth_Grade_8_Lbl                                                              60th
# NWEA_Reading_Attainment_Grade_2_Pct                                                         33
# NWEA_Reading_Attainment_Grade_2_Lbl                                                       33rd
# NWEA_Reading_Attainment_Grade_3_Pct                                                         39
# NWEA_Reading_Attainment_Grade_3_Lbl                                                       39th
# NWEA_Reading_Attainment_Grade_4_Pct                                                         64
# NWEA_Reading_Attainment_Grade_4_Lbl                                                       64th
# ...
# Freshmen_On_Track_School_Pct_Year_2                                                        NaN
# Freshmen_On_Track_CPS_Pct_Year_2                                                          84.1
# Freshmen_On_Track_School_Pct_Year_1                                                        NaN
# Freshmen_On_Track_CPS_Pct_Year_1                                                          82.6
# College_Enrollment_School_Pct_Year_2                                                       NaN
# College_Enrollment_CPS_Pct_Year_2                                                         58.7
# College_Enrollment_School_Pct_Year_1                                                       NaN
# College_Enrollment_CPS_Pct_Year_1                                                         58.1
# College_Persistence_School_Pct_Year_2                                                      NaN
# College_Persistence_CPS_Pct_Year_2                                                          70
# College_Persistence_School_Pct_Year_1                                                      NaN
# College_Persistence_CPS_Pct_Year_1                                                        70.1
# Progress_Toward_Graduation_Year_1                                                         2014
# Progress_Toward_Graduation_Year_2                                                         2015
# Mobility_Rate_Pct                                                                         32.8
# Chronic_Truancy_Pct                                                                        NaN
# School_Survey_Rating_Description             This school is “Well-Organized for Improvement...
# Supportive_School_Award                                                              NOT RATED
# Supportive_School_Award_Desc                 This school is in the process of being reviewe...
# Parent_Survey_Results_Year                                                                2015
# School_Latitude                                                                        41.7608
# School_Longitude                                                                      -87.5761
#
#                                                                                            669
# School_ID                                                                               400135
# Long_Name                                                     YCCS-Latino Youth Alternative HS
# School_Type                                                                            Charter
# Primary_Category                                                                            HS
# Progress_Report_Year                                                                      2015
# Blue_Ribbon_Award_Year                                                                     NaN
# Excelerate_Award_Gold_Year                                                                 NaN
# Spot_Light_Award_Year                                                                      NaN
# Improvement_Award_Year                                                                     NaN
# Excellence_Award_Year                                                                      NaN
# Student_Growth_Rating                                                        NO DATA AVAILABLE
# Student_Growth_Description                   Student Growth measures the change in standard...
# Growth_Reading_Grades_Tested_Pct_ES                                                        NaN
# Growth_Reading_Grades_Tested_Label_ES                                                      NaN
# Growth_Math_Grades_Tested_Pct_ES                                                           NaN
# Growth_Math_Grades_Tested_Label_ES                                                         NaN
# Student_Attainment_Rating                                                    FAR BELOW AVERAGE
# Student_Attainment_Description               Student Attainment measures how well the schoo...
# Attainment_Reading_Pct_ES                                                                  NaN
# Attainment_Reading_Lbl_ES                                                                  NaN
# Attainment_Math_Pct_ES                                                                     NaN
# Attainment_Math_Lbl_ES                                                                     NaN
# Culture_Climate_Rating                                                     PARTIALLY ORGANIZED
# Culture_Climate_Description                  Results are based on student and teacher respo...
# School_Survey_Student_Response_Rate_Pct                                                   64.1
# School_Survey_Student_Response_Rate_Avg_Pct                                               81.2
# School_Survey_Teacher_Response_Rate_Pct                                                   99.9
# School_Survey_Teacher_Response_Rate_Avg_Pct                                               80.7
# Healthy_School_Certification                                                     NOT CERTIFIED
# Healthy_School_Certification_Description     This school has not achieved Healthy School Ce...
# Creative_School_Certification                                                              NaN
# Creative_School_Certification_Description    This school has an arts designation of Incompl...
# NWEA_Reading_Growth_Grade_3_Pct                                                            NaN
# NWEA_Reading_Growth_Grade_3_Lbl                                                            NaN
# NWEA_Reading_Growth_Grade_4_Pct                                                            NaN
# NWEA_Reading_Growth_Grade_4_Lbl                                                            NaN
# NWEA_Reading_Growth_Grade_5_Pct                                                            NaN
# NWEA_Reading_Growth_Grade_5_Lbl                                                            NaN
# NWEA_Reading_Growth_Grade_6_Pct                                                            NaN
# NWEA_Reading_Growth_Grade_6_Lbl                                                            NaN
# NWEA_Reading_Growth_Grade_7_Pct                                                            NaN
# NWEA_Reading_Growth_Grade_7_Lbl                                                            NaN
# NWEA_Reading_Growth_Grade_8_Pct                                                            NaN
# NWEA_Reading_Growth_Grade_8_Lbl                                                            NaN
# NWEA_Math_Growth_Grade_3_Pct                                                               NaN
# NWEA_Math_Growth_Grade_3_Lbl                                                               NaN
# NWEA_Math_Growth_Grade_4_Pct                                                               NaN
# NWEA_Math_Growth_Grade_4_Lbl                                                               NaN
# NWEA_Math_Growth_Grade_5_Pct                                                               NaN
# NWEA_Math_Growth_Grade_5_Lbl                                                               NaN
# NWEA_Math_Growth_Grade_6_Pct                                                               NaN
# NWEA_Math_Growth_Grade_6_Lbl                                                               NaN
# NWEA_Math_Growth_Grade_7_Pct                                                               NaN
# NWEA_Math_Growth_Grade_7_Lbl                                                               NaN
# NWEA_Math_Growth_Grade_8_Pct                                                               NaN
# NWEA_Math_Growth_Grade_8_Lbl                                                               NaN
# NWEA_Reading_Attainment_Grade_2_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_2_Lbl                                                        NaN
# NWEA_Reading_Attainment_Grade_3_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_3_Lbl                                                        NaN
# NWEA_Reading_Attainment_Grade_4_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_4_Lbl                                                        NaN
# NWEA_Reading_Attainment_Grade_5_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_5_Lbl                                                        NaN
# NWEA_Reading_Attainment_Grade_6_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_6_Lbl                                                        NaN
# NWEA_Reading_Attainment_Grade_7_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_7_Lbl                                                        NaN
# NWEA_Reading_Attainment_Grade_8_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_8_Lbl                                                        NaN
# NWEA_Math_Attainment_Grade_2_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_2_Lbl                                                           NaN
# NWEA_Math_Attainment_Grade_3_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_3_Lbl                                                           NaN
# NWEA_Math_Attainment_Grade_4_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_4_Lbl                                                           NaN
# NWEA_Math_Attainment_Grade_5_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_5_Lbl                                                           NaN
# NWEA_Math_Attainment_Grade_6_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_6_Lbl                                                           NaN
# NWEA_Math_Attainment_Grade_7_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_7_Lbl                                                           NaN
# NWEA_Math_Attainment_Grade_8_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_8_Lbl                                                           NaN
# School_Survey_Involved_Families                                                      VERY WEAK
# School_Survey_Supportive_Environment                                                   NEUTRAL
# School_Survey_Ambitious_Instruction                                                    NEUTRAL
# School_Survey_Effective_Leaders                                                        NEUTRAL
# School_Survey_Collaborative_Teachers                                                   NEUTRAL
# School_Survey_Safety                                                                      WEAK
# Suspensions_Per_100_Students_Year_1_Pct                                                    NaN
# Suspensions_Per_100_Students_Year_2_Pct                                                    NaN
# Suspensions_Per_100_Students_Avg_Pct                                                      20.8
# Misconducts_To_Suspensions_Year_1_Pct                                                      NaN
# Misconducts_To_Suspensions_Year_2_Pct                                                      NaN
# Misconducts_To_Suspensions_Avg_Pct                                                        18.3
# Average_Length_Suspension_Year_1_Pct                                                       NaN
# Average_Length_Suspension_Year_2_Pct                                                       NaN
# Average_Length_Suspension_Avg_Pct                                                     2.5 days
# Behavior_Discipline_Year_1                                                                2014
# Behavior_Discipline_Year_2                                                                2015
# School_Survey_School_Community                                                             NaN
# School_Survey_Parent_Teacher_Partnership                                                   NaN
# School_Survey_Quality_Of_Facilities                                                        NaN
# Student_Attendance_Year_1_Pct                                                               78
# Student_Attendance_Year_2_Pct                                                             73.3
# Student_Attendance_Avg_Pct                                                                88.8
# Teacher_Attendance_Year_1_Pct                                                              NaN
# Teacher_Attendance_Year_2_Pct                                                              NaN
# Teacher_Attendance_Avg_Pct                                                                 NaN
# One_Year_Dropout_Rate_Year_1_Pct                                                          31.3
# One_Year_Dropout_Rate_Year_2_Pct                                                          39.4
# One_Year_Dropout_Rate_Avg_Pct                                                              7.9
# Other_Metrics_Year_1                                                                      2014
# Other_Metrics_Year_2                                                                      2015
# Growth_ACT_Grade_11_Pct                                                                    NaN
# Growth_ACT_Grade_11_Lbl                                                                    NaN
# Attainment_ACT_Grade_11_Pct                                                                  4
# Attainment_ACT_Grade_11_Lbl                                                                4th
# Freshmen_On_Track_School_Pct_Year_2                                                        NaN
# Freshmen_On_Track_CPS_Pct_Year_2                                                          84.1
# Freshmen_On_Track_School_Pct_Year_1                                                        NaN
# Freshmen_On_Track_CPS_Pct_Year_1                                                          82.6
# College_Enrollment_School_Pct_Year_2                                                       9.8
# College_Enrollment_CPS_Pct_Year_2                                                         58.7
# College_Enrollment_School_Pct_Year_1                                                      14.6
# College_Enrollment_CPS_Pct_Year_1                                                         58.1
# College_Persistence_School_Pct_Year_2                                                     33.3
# College_Persistence_CPS_Pct_Year_2                                                          70
# College_Persistence_School_Pct_Year_1                                                      NaN
# College_Persistence_CPS_Pct_Year_1                                                        70.1
# Progress_Toward_Graduation_Year_1                                                         2014
# Progress_Toward_Graduation_Year_2                                                         2015
# Mobility_Rate_Pct                                                                          NaN
# Chronic_Truancy_Pct                                                                        NaN
# School_Survey_Rating_Description             This school is “Partially Organized for Improv...
# Supportive_School_Award                                                              NOT RATED
# Supportive_School_Award_Desc                 This school is in the process of being reviewe...
# Parent_Survey_Results_Year                                                                2015
# School_Latitude                                                                        41.8547
# School_Longitude                                                                      -87.6954

# %% [markdown]
# There are large quantity of redundant columns - many of the data points give both a raw number and a percentage value.  I will drop the percentage values and retain the integer columns.  Additionally, there are "description" columns that provide insight into what the data represents but provide no data on the school itself - these columns will also be dropped.

# %%
lbl_col_list = df_201516.columns.tolist()
lbl_col_list = [x for x in lbl_col_list if 'Lbl' in x]
df_201516.drop(lbl_col_list, axis = 1, inplace = True)

label_col_list = df_201516.columns.tolist()
label_col_list = [x for x in label_col_list if 'Label' in x]
df_201516.drop(label_col_list, axis = 1, inplace = True)

description_col_list = df_201516.columns.tolist()
description_col_list = [x for x in description_col_list if 'Description' in x]
df_201516.drop(description_col_list, axis = 1, inplace = True)

# %% [markdown]
# There are also columns with information only relevant to high schools.  This data can also be removed since it will not be present for the schools within the scope of our analysis.

# %%
act_col_list = df_201516.columns.tolist()
act_col_list = [x for x in act_col_list if 'ACT' in x]
df_201516.drop(act_col_list, axis = 1, inplace = True)

freshman_col_list = df_201516.columns.tolist()
freshman_col_list = [x for x in freshman_col_list if 'Freshmen' in x]
df_201516.drop(freshman_col_list, axis = 1, inplace = True)

college_col_list = df_201516.columns.tolist()
college_col_list = [x for x in college_col_list if 'College' in x]
df_201516.drop(college_col_list, axis = 1, inplace = True)

# %%
display_all(df_201516.tail().T)
# Out:
#                                                                                            665  \
# School_ID                                                                               610173
# Long_Name                                                     Jesse Sherwood Elementary School
# School_Type                                                                       Neighborhood
# Primary_Category                                                                            ES
# Progress_Report_Year                                                                      2015
# Blue_Ribbon_Award_Year                                                                     NaN
# Excelerate_Award_Gold_Year                                                                 NaN
# Spot_Light_Award_Year                                                                      NaN
# Improvement_Award_Year                                                                     NaN
# Excellence_Award_Year                                                                      NaN
# Student_Growth_Rating                                                        FAR ABOVE AVERAGE
# Growth_Reading_Grades_Tested_Pct_ES                                                         99
# Growth_Math_Grades_Tested_Pct_ES                                                            99
# Student_Attainment_Rating                                                    FAR ABOVE AVERAGE
# Attainment_Reading_Pct_ES                                                                   96
# Attainment_Math_Pct_ES                                                                      93
# Culture_Climate_Rating                                                          WELL ORGANIZED
# School_Survey_Student_Response_Rate_Pct                                                   99.9
# School_Survey_Student_Response_Rate_Avg_Pct                                               81.2
# School_Survey_Teacher_Response_Rate_Pct                                                   95.8
# School_Survey_Teacher_Response_Rate_Avg_Pct                                               80.7
# Healthy_School_Certification                                                     NOT CERTIFIED
# Creative_School_Certification                                                        EXCELLING
# NWEA_Reading_Growth_Grade_3_Pct                                                             99
# NWEA_Reading_Growth_Grade_4_Pct                                                             99
# NWEA_Reading_Growth_Grade_5_Pct                                                             99
# NWEA_Reading_Growth_Grade_6_Pct                                                             99
# NWEA_Reading_Growth_Grade_7_Pct                                                             99
# NWEA_Reading_Growth_Grade_8_Pct                                                             79
# NWEA_Math_Growth_Grade_3_Pct                                                                99
# NWEA_Math_Growth_Grade_4_Pct                                                                99
# NWEA_Math_Growth_Grade_5_Pct                                                                99
# NWEA_Math_Growth_Grade_6_Pct                                                                99
# NWEA_Math_Growth_Grade_7_Pct                                                                99
# NWEA_Math_Growth_Grade_8_Pct                                                                99
# NWEA_Reading_Attainment_Grade_2_Pct                                                         95
# NWEA_Reading_Attainment_Grade_3_Pct                                                         86
# NWEA_Reading_Attainment_Grade_4_Pct                                                         99
# NWEA_Reading_Attainment_Grade_5_Pct                                                         97
# NWEA_Reading_Attainment_Grade_6_Pct                                                         88
# NWEA_Reading_Attainment_Grade_7_Pct                                                         73
# NWEA_Reading_Attainment_Grade_8_Pct                                                         58
# NWEA_Math_Attainment_Grade_2_Pct                                                            99
# NWEA_Math_Attainment_Grade_3_Pct                                                            82
# NWEA_Math_Attainment_Grade_4_Pct                                                            99
# NWEA_Math_Attainment_Grade_5_Pct                                                            75
# NWEA_Math_Attainment_Grade_6_Pct                                                            82
# NWEA_Math_Attainment_Grade_7_Pct                                                            88
# NWEA_Math_Attainment_Grade_8_Pct                                                            74
# School_Survey_Involved_Families                                                        NEUTRAL
# School_Survey_Supportive_Environment                                               VERY STRONG
# School_Survey_Ambitious_Instruction                                                VERY STRONG
# School_Survey_Effective_Leaders                                                         STRONG
# School_Survey_Collaborative_Teachers                                                    STRONG
# School_Survey_Safety                                                                    STRONG
# Suspensions_Per_100_Students_Year_1_Pct                                                    5.8
# Suspensions_Per_100_Students_Year_2_Pct                                                    1.7
# Suspensions_Per_100_Students_Avg_Pct                                                       3.8
# Misconducts_To_Suspensions_Year_1_Pct                                                     62.2
# Misconducts_To_Suspensions_Year_2_Pct                                                     18.2
# Misconducts_To_Suspensions_Avg_Pct                                                        18.4
# Average_Length_Suspension_Year_1_Pct                                                  2.7 days
# Average_Length_Suspension_Year_2_Pct                                                  2.7 days
# Average_Length_Suspension_Avg_Pct                                                     2.1 days
# Behavior_Discipline_Year_1                                                                2014
# Behavior_Discipline_Year_2                                                                2015
# School_Survey_School_Community                                                          Strong
# School_Survey_Parent_Teacher_Partnership                                               Neutral
# School_Survey_Quality_Of_Facilities                                                     Strong
# Student_Attendance_Year_1_Pct                                                               95
# Student_Attendance_Year_2_Pct                                                             95.9
# Student_Attendance_Avg_Pct                                                                95.1
# Teacher_Attendance_Year_1_Pct                                                             97.6
# Teacher_Attendance_Year_2_Pct                                                             96.3
# Teacher_Attendance_Avg_Pct                                                                  95
# One_Year_Dropout_Rate_Year_1_Pct                                                           NaN
# One_Year_Dropout_Rate_Year_2_Pct                                                           NaN
# One_Year_Dropout_Rate_Avg_Pct                                                              7.9
# Other_Metrics_Year_1                                                                      2014
# Other_Metrics_Year_2                                                                      2015
# Progress_Toward_Graduation_Year_1                                                         2014
# Progress_Toward_Graduation_Year_2                                                         2015
# Mobility_Rate_Pct                                                                         32.3
# Chronic_Truancy_Pct                                                                        NaN
# Supportive_School_Award                                                              NOT RATED
# Supportive_School_Award_Desc                 This school is in the process of being reviewe...
# Parent_Survey_Results_Year                                                                2015
# School_Latitude                                                                        41.7908
# School_Longitude                                                                      -87.6323
#
#                                                                                            666  \
# School_ID                                                                               610115
# Long_Name                                                         Park Manor Elementary School
# School_Type                                                                       Neighborhood
# Primary_Category                                                                            ES
# Progress_Report_Year                                                                      2015
# Blue_Ribbon_Award_Year                                                                     NaN
# Excelerate_Award_Gold_Year                                                                 NaN
# Spot_Light_Award_Year                                                                      NaN
# Improvement_Award_Year                                                                    2012
# Excellence_Award_Year                                                                      NaN
# Student_Growth_Rating                                                                  AVERAGE
# Growth_Reading_Grades_Tested_Pct_ES                                                         43
# Growth_Math_Grades_Tested_Pct_ES                                                            31
# Student_Attainment_Rating                                                        BELOW AVERAGE
# Attainment_Reading_Pct_ES                                                                   24
# Attainment_Math_Pct_ES                                                                      25
# Culture_Climate_Rating                                                          WELL ORGANIZED
# School_Survey_Student_Response_Rate_Pct                                                   87.7
# School_Survey_Student_Response_Rate_Avg_Pct                                               81.2
# School_Survey_Teacher_Response_Rate_Pct                                                   73.7
# School_Survey_Teacher_Response_Rate_Avg_Pct                                               80.7
# Healthy_School_Certification                                                     NOT CERTIFIED
# Creative_School_Certification                                                       DEVELOPING
# NWEA_Reading_Growth_Grade_3_Pct                                                             66
# NWEA_Reading_Growth_Grade_4_Pct                                                             74
# NWEA_Reading_Growth_Grade_5_Pct                                                              3
# NWEA_Reading_Growth_Grade_6_Pct                                                             57
# NWEA_Reading_Growth_Grade_7_Pct                                                             71
# NWEA_Reading_Growth_Grade_8_Pct                                                             16
# NWEA_Math_Growth_Grade_3_Pct                                                                 1
# NWEA_Math_Growth_Grade_4_Pct                                                                 2
# NWEA_Math_Growth_Grade_5_Pct                                                                30
# NWEA_Math_Growth_Grade_6_Pct                                                                81
# NWEA_Math_Growth_Grade_7_Pct                                                                95
# NWEA_Math_Growth_Grade_8_Pct                                                                60
# NWEA_Reading_Attainment_Grade_2_Pct                                                         40
# NWEA_Reading_Attainment_Grade_3_Pct                                                         25
# NWEA_Reading_Attainment_Grade_4_Pct                                                         23
# NWEA_Reading_Attainment_Grade_5_Pct                                                          7
# NWEA_Reading_Attainment_Grade_6_Pct                                                         30
# NWEA_Reading_Attainment_Grade_7_Pct                                                         58
# NWEA_Reading_Attainment_Grade_8_Pct                                                         19
# NWEA_Math_Attainment_Grade_2_Pct                                                            36
# NWEA_Math_Attainment_Grade_3_Pct                                                             4
# NWEA_Math_Attainment_Grade_4_Pct                                                             6
# NWEA_Math_Attainment_Grade_5_Pct                                                            16
# NWEA_Math_Attainment_Grade_6_Pct                                                            34
# NWEA_Math_Attainment_Grade_7_Pct                                                            67
# NWEA_Math_Attainment_Grade_8_Pct                                                            66
# School_Survey_Involved_Families                                                         STRONG
# School_Survey_Supportive_Environment                                                    STRONG
# School_Survey_Ambitious_Instruction                                                VERY STRONG
# School_Survey_Effective_Leaders                                                         STRONG
# School_Survey_Collaborative_Teachers                                               VERY STRONG
# School_Survey_Safety                                                                      WEAK
# Suspensions_Per_100_Students_Year_1_Pct                                                    2.9
# Suspensions_Per_100_Students_Year_2_Pct                                                    3.7
# Suspensions_Per_100_Students_Avg_Pct                                                       3.8
# Misconducts_To_Suspensions_Year_1_Pct                                                     47.6
# Misconducts_To_Suspensions_Year_2_Pct                                                     48.3
# Misconducts_To_Suspensions_Avg_Pct                                                        18.4
# Average_Length_Suspension_Year_1_Pct                                                  3.0 days
# Average_Length_Suspension_Year_2_Pct                                                  3.1 days
# Average_Length_Suspension_Avg_Pct                                                     2.1 days
# Behavior_Discipline_Year_1                                                                2014
# Behavior_Discipline_Year_2                                                                2015
# School_Survey_School_Community                                                             NaN
# School_Survey_Parent_Teacher_Partnership                                                   NaN
# School_Survey_Quality_Of_Facilities                                                        NaN
# Student_Attendance_Year_1_Pct                                                               96
# Student_Attendance_Year_2_Pct                                                             96.1
# Student_Attendance_Avg_Pct                                                                95.1
# Teacher_Attendance_Year_1_Pct                                                             95.5
# Teacher_Attendance_Year_2_Pct                                                             96.1
# Teacher_Attendance_Avg_Pct                                                                  95
# One_Year_Dropout_Rate_Year_1_Pct                                                           NaN
# One_Year_Dropout_Rate_Year_2_Pct                                                           NaN
# One_Year_Dropout_Rate_Avg_Pct                                                              7.9
# Other_Metrics_Year_1                                                                      2014
# Other_Metrics_Year_2                                                                      2015
# Progress_Toward_Graduation_Year_1                                                         2014
# Progress_Toward_Graduation_Year_2                                                         2015
# Mobility_Rate_Pct                                                                         41.2
# Chronic_Truancy_Pct                                                                        NaN
# Supportive_School_Award                                                              NOT RATED
# Supportive_School_Award_Desc                 This school is in the process of being reviewe...
# Parent_Survey_Results_Year                                                                2015
# School_Latitude                                                                        41.7665
# School_Longitude                                                                      -87.6115
#
#                                                                                            667  \
# School_ID                                                                               609996
# Long_Name                                                   Charles N Holden Elementary School
# School_Type                                                                       Neighborhood
# Primary_Category                                                                            ES
# Progress_Report_Year                                                                      2015
# Blue_Ribbon_Award_Year                                                                     NaN
# Excelerate_Award_Gold_Year                                                                2015
# Spot_Light_Award_Year                                                                      NaN
# Improvement_Award_Year                                                                     NaN
# Excellence_Award_Year                                                                      NaN
# Student_Growth_Rating                                                        FAR ABOVE AVERAGE
# Growth_Reading_Grades_Tested_Pct_ES                                                         71
# Growth_Math_Grades_Tested_Pct_ES                                                            93
# Student_Attainment_Rating                                                        ABOVE AVERAGE
# Attainment_Reading_Pct_ES                                                                   58
# Attainment_Math_Pct_ES                                                                      81
# Culture_Climate_Rating                                                          WELL ORGANIZED
# School_Survey_Student_Response_Rate_Pct                                                   88.6
# School_Survey_Student_Response_Rate_Avg_Pct                                               81.2
# School_Survey_Teacher_Response_Rate_Pct                                                   90.3
# School_Survey_Teacher_Response_Rate_Avg_Pct                                               80.7
# Healthy_School_Certification                                                     NOT CERTIFIED
# Creative_School_Certification                                                        EXCELLING
# NWEA_Reading_Growth_Grade_3_Pct                                                             28
# NWEA_Reading_Growth_Grade_4_Pct                                                             38
# NWEA_Reading_Growth_Grade_5_Pct                                                             58
# NWEA_Reading_Growth_Grade_6_Pct                                                             95
# NWEA_Reading_Growth_Grade_7_Pct                                                             90
# NWEA_Reading_Growth_Grade_8_Pct                                                             62
# NWEA_Math_Growth_Grade_3_Pct                                                                20
# NWEA_Math_Growth_Grade_4_Pct                                                                99
# NWEA_Math_Growth_Grade_5_Pct                                                                42
# NWEA_Math_Growth_Grade_6_Pct                                                                83
# NWEA_Math_Growth_Grade_7_Pct                                                                99
# NWEA_Math_Growth_Grade_8_Pct                                                                99
# NWEA_Reading_Attainment_Grade_2_Pct                                                         38
# NWEA_Reading_Attainment_Grade_3_Pct                                                         55
# NWEA_Reading_Attainment_Grade_4_Pct                                                         51
# NWEA_Reading_Attainment_Grade_5_Pct                                                         50
# NWEA_Reading_Attainment_Grade_6_Pct                                                         60
# NWEA_Reading_Attainment_Grade_7_Pct                                                         73
# NWEA_Reading_Attainment_Grade_8_Pct                                                         66
# NWEA_Math_Attainment_Grade_2_Pct                                                            53
# NWEA_Math_Attainment_Grade_3_Pct                                                            43
# NWEA_Math_Attainment_Grade_4_Pct                                                            75
# NWEA_Math_Attainment_Grade_5_Pct                                                            51
# NWEA_Math_Attainment_Grade_6_Pct                                                            83
# NWEA_Math_Attainment_Grade_7_Pct                                                            97
# NWEA_Math_Attainment_Grade_8_Pct                                                            97
# School_Survey_Involved_Families                                                         STRONG
# School_Survey_Supportive_Environment                                                    STRONG
# School_Survey_Ambitious_Instruction                                                     STRONG
# School_Survey_Effective_Leaders                                                        NEUTRAL
# School_Survey_Collaborative_Teachers                                                    STRONG
# School_Survey_Safety                                                                   NEUTRAL
# Suspensions_Per_100_Students_Year_1_Pct                                                    4.4
# Suspensions_Per_100_Students_Year_2_Pct                                                      3
# Suspensions_Per_100_Students_Avg_Pct                                                       3.8
# Misconducts_To_Suspensions_Year_1_Pct                                                     61.5
# Misconducts_To_Suspensions_Year_2_Pct                                                     28.1
# Misconducts_To_Suspensions_Avg_Pct                                                        18.4
# Average_Length_Suspension_Year_1_Pct                                                  2.5 days
# Average_Length_Suspension_Year_2_Pct                                                  1.9 days
# Average_Length_Suspension_Avg_Pct                                                     2.1 days
# Behavior_Discipline_Year_1                                                                2014
# Behavior_Discipline_Year_2                                                                2015
# School_Survey_School_Community                                                         Neutral
# School_Survey_Parent_Teacher_Partnership                                               Neutral
# School_Survey_Quality_Of_Facilities                                                    Neutral
# Student_Attendance_Year_1_Pct                                                             94.5
# Student_Attendance_Year_2_Pct                                                             94.8
# Student_Attendance_Avg_Pct                                                                95.1
# Teacher_Attendance_Year_1_Pct                                                             95.5
# Teacher_Attendance_Year_2_Pct                                                             94.3
# Teacher_Attendance_Avg_Pct                                                                  95
# One_Year_Dropout_Rate_Year_1_Pct                                                           NaN
# One_Year_Dropout_Rate_Year_2_Pct                                                           NaN
# One_Year_Dropout_Rate_Avg_Pct                                                              7.9
# Other_Metrics_Year_1                                                                      2014
# Other_Metrics_Year_2                                                                      2015
# Progress_Toward_Graduation_Year_1                                                         2014
# Progress_Toward_Graduation_Year_2                                                         2015
# Mobility_Rate_Pct                                                                         14.2
# Chronic_Truancy_Pct                                                                        NaN
# Supportive_School_Award                                                              NOT RATED
# Supportive_School_Award_Desc                 This school is in the process of being reviewe...
# Parent_Survey_Results_Year                                                                2015
# School_Latitude                                                                         41.838
# School_Longitude                                                                      -87.6538
#
#                                                                                            668  \
# School_ID                                                                               609815
# Long_Name                                           Edward A Bouchet Math & Science Academy ES
# School_Type                                                                       Neighborhood
# Primary_Category                                                                            ES
# Progress_Report_Year                                                                      2015
# Blue_Ribbon_Award_Year                                                                     NaN
# Excelerate_Award_Gold_Year                                                                 NaN
# Spot_Light_Award_Year                                                                      NaN
# Improvement_Award_Year                                                                     NaN
# Excellence_Award_Year                                                                      NaN
# Student_Growth_Rating                                                            ABOVE AVERAGE
# Growth_Reading_Grades_Tested_Pct_ES                                                         95
# Growth_Math_Grades_Tested_Pct_ES                                                            67
# Student_Attainment_Rating                                                              AVERAGE
# Attainment_Reading_Pct_ES                                                                   52
# Attainment_Math_Pct_ES                                                                      39
# Culture_Climate_Rating                                                          WELL ORGANIZED
# School_Survey_Student_Response_Rate_Pct                                                   99.9
# School_Survey_Student_Response_Rate_Avg_Pct                                               81.2
# School_Survey_Teacher_Response_Rate_Pct                                                   99.9
# School_Survey_Teacher_Response_Rate_Avg_Pct                                               80.7
# Healthy_School_Certification                                         HEALTHY SCHOOLS CERTIFIED
# Creative_School_Certification                                                        EXCELLING
# NWEA_Reading_Growth_Grade_3_Pct                                                             81
# NWEA_Reading_Growth_Grade_4_Pct                                                             99
# NWEA_Reading_Growth_Grade_5_Pct                                                             58
# NWEA_Reading_Growth_Grade_6_Pct                                                             78
# NWEA_Reading_Growth_Grade_7_Pct                                                             92
# NWEA_Reading_Growth_Grade_8_Pct                                                             93
# NWEA_Math_Growth_Grade_3_Pct                                                                64
# NWEA_Math_Growth_Grade_4_Pct                                                                99
# NWEA_Math_Growth_Grade_5_Pct                                                                60
# NWEA_Math_Growth_Grade_6_Pct                                                                44
# NWEA_Math_Growth_Grade_7_Pct                                                                22
# NWEA_Math_Growth_Grade_8_Pct                                                                60
# NWEA_Reading_Attainment_Grade_2_Pct                                                         33
# NWEA_Reading_Attainment_Grade_3_Pct                                                         39
# NWEA_Reading_Attainment_Grade_4_Pct                                                         64
# NWEA_Reading_Attainment_Grade_5_Pct                                                         42
# NWEA_Reading_Attainment_Grade_6_Pct                                                         48
# NWEA_Reading_Attainment_Grade_7_Pct                                                         71
# NWEA_Reading_Attainment_Grade_8_Pct                                                         74
# NWEA_Math_Attainment_Grade_2_Pct                                                            33
# NWEA_Math_Attainment_Grade_3_Pct                                                            24
# NWEA_Math_Attainment_Grade_4_Pct                                                            63
# NWEA_Math_Attainment_Grade_5_Pct                                                            29
# NWEA_Math_Attainment_Grade_6_Pct                                                            21
# NWEA_Math_Attainment_Grade_7_Pct                                                            57
# NWEA_Math_Attainment_Grade_8_Pct                                                            63
# School_Survey_Involved_Families                                                    VERY STRONG
# School_Survey_Supportive_Environment                                               VERY STRONG
# School_Survey_Ambitious_Instruction                                                VERY STRONG
# School_Survey_Effective_Leaders                                                         STRONG
# School_Survey_Collaborative_Teachers                                               VERY STRONG
# School_Survey_Safety                                                                   NEUTRAL
# Suspensions_Per_100_Students_Year_1_Pct                                                   20.7
# Suspensions_Per_100_Students_Year_2_Pct                                                    9.4
# Suspensions_Per_100_Students_Avg_Pct                                                       3.8
# Misconducts_To_Suspensions_Year_1_Pct                                                     82.4
# Misconducts_To_Suspensions_Year_2_Pct                                                     24.1
# Misconducts_To_Suspensions_Avg_Pct                                                        18.4
# Average_Length_Suspension_Year_1_Pct                                                  1.9 days
# Average_Length_Suspension_Year_2_Pct                                                  2.2 days
# Average_Length_Suspension_Avg_Pct                                                     2.1 days
# Behavior_Discipline_Year_1                                                                2014
# Behavior_Discipline_Year_2                                                                2015
# School_Survey_School_Community                                                         Neutral
# School_Survey_Parent_Teacher_Partnership                                                Strong
# School_Survey_Quality_Of_Facilities                                                     Strong
# Student_Attendance_Year_1_Pct                                                               94
# Student_Attendance_Year_2_Pct                                                             93.9
# Student_Attendance_Avg_Pct                                                                95.1
# Teacher_Attendance_Year_1_Pct                                                             96.2
# Teacher_Attendance_Year_2_Pct                                                             95.8
# Teacher_Attendance_Avg_Pct                                                                  95
# One_Year_Dropout_Rate_Year_1_Pct                                                           NaN
# One_Year_Dropout_Rate_Year_2_Pct                                                           NaN
# One_Year_Dropout_Rate_Avg_Pct                                                              7.9
# Other_Metrics_Year_1                                                                      2014
# Other_Metrics_Year_2                                                                      2015
# Progress_Toward_Graduation_Year_1                                                         2014
# Progress_Toward_Graduation_Year_2                                                         2015
# Mobility_Rate_Pct                                                                         32.8
# Chronic_Truancy_Pct                                                                        NaN
# Supportive_School_Award                                                              NOT RATED
# Supportive_School_Award_Desc                 This school is in the process of being reviewe...
# Parent_Survey_Results_Year                                                                2015
# School_Latitude                                                                        41.7608
# School_Longitude                                                                      -87.5761
#
#                                                                                            669
# School_ID                                                                               400135
# Long_Name                                                     YCCS-Latino Youth Alternative HS
# School_Type                                                                            Charter
# Primary_Category                                                                            HS
# Progress_Report_Year                                                                      2015
# Blue_Ribbon_Award_Year                                                                     NaN
# Excelerate_Award_Gold_Year                                                                 NaN
# Spot_Light_Award_Year                                                                      NaN
# Improvement_Award_Year                                                                     NaN
# Excellence_Award_Year                                                                      NaN
# Student_Growth_Rating                                                        NO DATA AVAILABLE
# Growth_Reading_Grades_Tested_Pct_ES                                                        NaN
# Growth_Math_Grades_Tested_Pct_ES                                                           NaN
# Student_Attainment_Rating                                                    FAR BELOW AVERAGE
# Attainment_Reading_Pct_ES                                                                  NaN
# Attainment_Math_Pct_ES                                                                     NaN
# Culture_Climate_Rating                                                     PARTIALLY ORGANIZED
# School_Survey_Student_Response_Rate_Pct                                                   64.1
# School_Survey_Student_Response_Rate_Avg_Pct                                               81.2
# School_Survey_Teacher_Response_Rate_Pct                                                   99.9
# School_Survey_Teacher_Response_Rate_Avg_Pct                                               80.7
# Healthy_School_Certification                                                     NOT CERTIFIED
# Creative_School_Certification                                                              NaN
# NWEA_Reading_Growth_Grade_3_Pct                                                            NaN
# NWEA_Reading_Growth_Grade_4_Pct                                                            NaN
# NWEA_Reading_Growth_Grade_5_Pct                                                            NaN
# NWEA_Reading_Growth_Grade_6_Pct                                                            NaN
# NWEA_Reading_Growth_Grade_7_Pct                                                            NaN
# NWEA_Reading_Growth_Grade_8_Pct                                                            NaN
# NWEA_Math_Growth_Grade_3_Pct                                                               NaN
# NWEA_Math_Growth_Grade_4_Pct                                                               NaN
# NWEA_Math_Growth_Grade_5_Pct                                                               NaN
# NWEA_Math_Growth_Grade_6_Pct                                                               NaN
# NWEA_Math_Growth_Grade_7_Pct                                                               NaN
# NWEA_Math_Growth_Grade_8_Pct                                                               NaN
# NWEA_Reading_Attainment_Grade_2_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_3_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_4_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_5_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_6_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_7_Pct                                                        NaN
# NWEA_Reading_Attainment_Grade_8_Pct                                                        NaN
# NWEA_Math_Attainment_Grade_2_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_3_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_4_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_5_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_6_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_7_Pct                                                           NaN
# NWEA_Math_Attainment_Grade_8_Pct                                                           NaN
# School_Survey_Involved_Families                                                      VERY WEAK
# School_Survey_Supportive_Environment                                                   NEUTRAL
# School_Survey_Ambitious_Instruction                                                    NEUTRAL
# School_Survey_Effective_Leaders                                                        NEUTRAL
# School_Survey_Collaborative_Teachers                                                   NEUTRAL
# School_Survey_Safety                                                                      WEAK
# Suspensions_Per_100_Students_Year_1_Pct                                                    NaN
# Suspensions_Per_100_Students_Year_2_Pct                                                    NaN
# Suspensions_Per_100_Students_Avg_Pct                                                      20.8
# Misconducts_To_Suspensions_Year_1_Pct                                                      NaN
# Misconducts_To_Suspensions_Year_2_Pct                                                      NaN
# Misconducts_To_Suspensions_Avg_Pct                                                        18.3
# Average_Length_Suspension_Year_1_Pct                                                       NaN
# Average_Length_Suspension_Year_2_Pct                                                       NaN
# Average_Length_Suspension_Avg_Pct                                                     2.5 days
# Behavior_Discipline_Year_1                                                                2014
# Behavior_Discipline_Year_2                                                                2015
# School_Survey_School_Community                                                             NaN
# School_Survey_Parent_Teacher_Partnership                                                   NaN
# School_Survey_Quality_Of_Facilities                                                        NaN
# Student_Attendance_Year_1_Pct                                                               78
# Student_Attendance_Year_2_Pct                                                             73.3
# Student_Attendance_Avg_Pct                                                                88.8
# Teacher_Attendance_Year_1_Pct                                                              NaN
# Teacher_Attendance_Year_2_Pct                                                              NaN
# Teacher_Attendance_Avg_Pct                                                                 NaN
# One_Year_Dropout_Rate_Year_1_Pct                                                          31.3
# One_Year_Dropout_Rate_Year_2_Pct                                                          39.4
# One_Year_Dropout_Rate_Avg_Pct                                                              7.9
# Other_Metrics_Year_1                                                                      2014
# Other_Metrics_Year_2                                                                      2015
# Progress_Toward_Graduation_Year_1                                                         2014
# Progress_Toward_Graduation_Year_2                                                         2015
# Mobility_Rate_Pct                                                                          NaN
# Chronic_Truancy_Pct                                                                        NaN
# Supportive_School_Award                                                              NOT RATED
# Supportive_School_Award_Desc                 This school is in the process of being reviewe...
# Parent_Survey_Results_Year                                                                2015
# School_Latitude                                                                        41.8547
# School_Longitude                                                                      -87.6954

# %% [markdown]
# There are a few other final columns that are either redundant or irrevalent that I will remove.

# %%
final_remove_list = ['Parent_Survey_Results_Year', 'Supportive_School_Award_Desc', 'Progress_Toward_Graduation_Year_2','Progress_Toward_Graduation_Year_1','Other_Metrics_Year_2','Other_Metrics_Year_1']
df_201516.drop(final_remove_list, axis = 1, inplace = True)

# %% [markdown]
# With the columns now sufficiently cleaned based on description, we can remove *rows*.  Since this analysis is focused on elementary schools, I will drop all entries that pertain to high schools and middle schools.

# %%
df_201516.drop(df_201516[df_201516.Primary_Category == 'HS'].index, axis = 0, inplace = True)
df_201516.drop(df_201516[df_201516.Primary_Category == 'MS'].index, axis = 0, inplace = True)
df_201516.shape
# Out:
# (472, 83)

# %% [markdown]
# I will now repeat this cleaning process over the other files before preparing a final join of the DataFrames.

# %%
#drop school description cols
cols_to_drop = ['Address','Short_Name','Fax', 'City','State','Phone','CPS_School_Profile','Website', 'Empty_Progress_Report_Message', 'State_School_Report_Card_URL', 'Location','Zip']
df_201617.drop(cols_to_drop, axis = 1, inplace = True)

# %%
#drop label and description columns
column_names = df_201617.columns.tolist()
lbl_col_list = [x for x in column_names if 'Lbl' in x]
df_201617.drop(lbl_col_list, axis = 1, inplace = True)

label_col_list = [x for x in column_names if 'Label' in x]
df_201617.drop(label_col_list, axis = 1, inplace = True)

description_col_list = [x for x in column_names if 'Description' in x]
df_201617.drop(description_col_list, axis = 1, inplace = True)

# %%
#drop hs-only columns
column_names = df_201617.columns.tolist()
act_col_list = [x for x in column_names if 'ACT' in x]
df_201617.drop(act_col_list, axis = 1, inplace = True)

freshman_col_list = [x for x in column_names if 'Freshmen' in x]
df_201617.drop(freshman_col_list, axis = 1, inplace = True)

college_col_list = [x for x in column_names if 'College' in x]
df_201617.drop(college_col_list, axis = 1, inplace = True)

# %%
final_remove_list = ['Parent_Survey_Results_Year', 'Supportive_School_Award_Desc', 'Progress_Toward_Graduation_Year_2','Progress_Toward_Graduation_Year_1','Other_Metrics_Year_2','Other_Metrics_Year_1']
df_201617.drop(final_remove_list, axis = 1, inplace = True)

# %%
df_201617.drop(df_201617[df_201617.Primary_Category == 'HS'].index, axis = 0, inplace = True)
df_201617.drop(df_201617[df_201617.Primary_Category == 'MS'].index, axis = 0, inplace = True)
df_201617.shape
# Out:
# (470, 91)

# %% [markdown]
# Since this preprocessing arrived at a diffferent total number of columns, I will examine the columns that were added into the dataset between 2015-16 and 2016-17.

# %%
list_2015_cols = df_201516.columns.tolist()
list_2016_cols = df_201617.columns.tolist()
diff_list = np.setdiff1d(list_2016_cols,list_2015_cols)
print(diff_list)
# Out:
# ['Graduation_4_Year_CPS_Pct_Year_1' 'Graduation_4_Year_CPS_Pct_Year_2'
#  'Graduation_4_Year_School_Pct_Year_1'
#  'Graduation_4_Year_School_Pct_Year_2' 'Graduation_5_Year_CPS_Pct_Year_1'
#  'Graduation_5_Year_CPS_Pct_Year_2' 'Graduation_5_Year_School_Pct_Year_1'
#  'Graduation_5_Year_School_Pct_Year_2']

# %% [markdown]
# Since these new columns don't show values for elementary schools, I will drop them.

# %%
df_201617.drop(diff_list, axis = 1, inplace = True)

# %% [markdown]
# I will now prepare the 2017-18 data.

# %%
#drop school description cols
cols_to_drop = ['Short_Name','Fax', 'Phone','CPS_School_Profile','Website', 'Empty_Progress_Report_Message', 'State_School_Report_Card_URL', 'Location']
df_201718.drop(cols_to_drop, axis = 1, inplace = True)

#drop label and description columns
column_names = df_201718.columns.tolist()
lbl_col_list = [x for x in column_names if 'Lbl' in x]
df_201718.drop(lbl_col_list, axis = 1, inplace = True)

label_col_list = [x for x in column_names if 'Label' in x]
df_201718.drop(label_col_list, axis = 1, inplace = True)

description_col_list = [x for x in column_names if 'Description' in x]
df_201718.drop(description_col_list, axis = 1, inplace = True)

#drop hs-only columns
column_names = df_201718.columns.tolist()
act_col_list = [x for x in column_names if 'SAT' in x]
df_201718.drop(act_col_list, axis = 1, inplace = True)

freshman_col_list = [x for x in column_names if 'Freshmen' in x]
df_201718.drop(freshman_col_list, axis = 1, inplace = True)

college_col_list = [x for x in column_names if 'College' in x]
df_201718.drop(college_col_list, axis = 1, inplace = True)

final_remove_list = ['Parent_Survey_Results_Year', 'Supportive_School_Award_Desc', 'Progress_Toward_Graduation_Year_2','Progress_Toward_Graduation_Year_1','Other_Metrics_Year_2','Other_Metrics_Year_1']
df_201718.drop(final_remove_list, axis = 1, inplace = True)

df_201718.drop(df_201718[df_201718.Primary_Category == 'HS'].index, axis = 0, inplace = True)
df_201718.drop(df_201718[df_201718.Primary_Category == 'MS'].index, axis = 0, inplace = True)
df_201718.shape
# Out:
# (472, 91)

# %% [markdown]
# Again, there are additional columns from the previous year's report, so I will again review these added columns and remove or retain as apporpriate.

# %%
list_2016_cols = df_201617.columns.tolist()
list_2017_cols = df_201718.columns.tolist()
diff_list = np.setdiff1d(list_2017_cols,list_2016_cols).tolist()
print(diff_list)
# Out:
# ['Graduation_4_Year_CPS_Pct_Year_1', 'Graduation_4_Year_CPS_Pct_Year_2', 'Graduation_4_Year_School_Pct_Year_1', 'Graduation_4_Year_School_Pct_Year_2', 'Graduation_5_Year_CPS_Pct_Year_1', 'Graduation_5_Year_CPS_Pct_Year_2', 'Graduation_5_Year_School_Pct_Year_1', 'Graduation_5_Year_School_Pct_Year_2', 'School_Survey_Parent_Response_Rate_Avg_Pct', 'School_Survey_Parent_Response_Rate_Pct']

# %% [markdown]
# Only one of these values apepars worth retaining, so I will preserve the Parent Response Rate column and remove the others.

# %%
diff_list.remove('School_Survey_Parent_Response_Rate_Pct')
df_201718.drop(diff_list, axis = 1, inplace = True)
df_201718.shape
# Out:
# (472, 82)

# %% [markdown]
# Repeating this process, I move into the 2018-19 data.

# %%
#drop school description cols
cols_to_drop = ['Short_Name','Fax', 'Phone','City', 'Address','State', 'Zip', 'CPS_School_Profile','Website', 'Empty_Progress_Report_Message', 'State_School_Report_Card_URL']
df_201819.drop(cols_to_drop, axis = 1, inplace = True)

#drop label and description columns
column_names = df_201819.columns.tolist()
lbl_col_list = [x for x in column_names if 'Lbl' in x]
df_201819.drop(lbl_col_list, axis = 1, inplace = True)

label_col_list = [x for x in column_names if 'Label' in x]
df_201819.drop(label_col_list, axis = 1, inplace = True)

description_col_list = [x for x in column_names if 'Description' in x]
df_201819.drop(description_col_list, axis = 1, inplace = True)

#drop hs-only columns
column_names = df_201819.columns.tolist()
act_col_list = [x for x in column_names if 'SAT' in x]
df_201819.drop(act_col_list, axis = 1, inplace = True)

freshman_col_list = [x for x in column_names if 'Freshmen' in x]
df_201819.drop(freshman_col_list, axis = 1, inplace = True)

college_col_list = [x for x in column_names if 'College' in x]
df_201819.drop(college_col_list, axis = 1, inplace = True)

final_remove_list = ['Parent_Survey_Results_Year', 'Supportive_School_Award_Desc', 'Progress_Toward_Graduation_Year_2','Progress_Toward_Graduation_Year_1','Other_Metrics_Year_2','Other_Metrics_Year_1']
df_201819.drop(final_remove_list, axis = 1, inplace = True)

df_201819.drop(df_201819[df_201819.Primary_Category == 'HS'].index, axis = 0, inplace = True)
df_201819.drop(df_201819[df_201819.Primary_Category == 'MS'].index, axis = 0, inplace = True)
df_201819.shape
# Out:
# (470, 94)

# %%
list_2017_cols = df_201718.columns.tolist()
list_2018_cols = df_201819.columns.tolist()
diff_list = np.setdiff1d(list_2018_cols,list_2017_cols).tolist()
print(diff_list)
# Out:
# ['Attainment_All_Grades_School_Pct', 'Graduation_4_Year_CPS_Pct_Year_1', 'Graduation_4_Year_CPS_Pct_Year_2', 'Graduation_4_Year_School_Pct_Year_1', 'Graduation_4_Year_School_Pct_Year_2', 'Graduation_5_Year_CPS_Pct_Year_1', 'Graduation_5_Year_CPS_Pct_Year_2', 'Graduation_5_Year_School_Pct_Year_1', 'Graduation_5_Year_School_Pct_Year_2', 'School_Latitude', 'School_Longitude', 'School_Survey_Parent_Response_Rate_Avg_Pct']

# %%
df_201819.drop(diff_list, axis = 1, inplace = True)
df_201819.shape
# Out:
# (470, 82)

# %% [markdown]
# Finally, we can combine the datasets into a single DataFrame for analysis.

# %%
list_2017_cols = df_201718.columns.tolist()
list_2018_cols = df_201819.columns.tolist()
diff_list = np.setdiff1d(list_2018_cols,list_2017_cols).tolist()
print(diff_list)
# Out:
# []

# %%
list_2016_cols = df_201617.columns.tolist()
list_2017_cols = df_201718.columns.tolist()
diff_list = np.setdiff1d(list_2017_cols,list_2016_cols).tolist()
print(diff_list)
# Out:
# ['School_Survey_Parent_Response_Rate_Pct']

# %%
df_raw = df_201819.append(df_201718).append(df_201617).append(df_201516)
df_raw.reset_index(inplace = True)
display_all(df_raw.tail().T)
# Out:
#                                                                             1879  \
# index                                                                        664
# School_ID                                                                 610339
# Long_Name                                    Amos Alonzo Stagg Elementary School
# School_Type                                                         Neighborhood
# Primary_Category                                                              ES
# Progress_Report_Year                                                        2015
# Blue_Ribbon_Award_Year                                                       NaN
# Excelerate_Award_Gold_Year                                                   NaN
# Spot_Light_Award_Year                                                        NaN
# Improvement_Award_Year                                                       NaN
# Excellence_Award_Year                                                        NaN
# Student_Growth_Rating                                              BELOW AVERAGE
# Growth_Reading_Grades_Tested_Pct_ES                                           22
# Growth_Math_Grades_Tested_Pct_ES                                              26
# Student_Attainment_Rating                                          BELOW AVERAGE
# Attainment_Reading_Pct_ES                                                     16
# Attainment_Math_Pct_ES                                                        20
# Culture_Climate_Rating                                         NOT YET ORGANIZED
# School_Survey_Student_Response_Rate_Pct                                       82
# School_Survey_Student_Response_Rate_Avg_Pct                                 81.2
# School_Survey_Teacher_Response_Rate_Pct                                     51.5
# School_Survey_Teacher_Response_Rate_Avg_Pct                                 80.7
# School_Survey_Parent_Response_Rate_Pct                                       NaN
# Healthy_School_Certification                                       NOT CERTIFIED
# Creative_School_Certification                                           EMERGING
# NWEA_Reading_Growth_Grade_3_Pct                                               27
# NWEA_Reading_Growth_Grade_4_Pct                                                5
# NWEA_Reading_Growth_Grade_5_Pct                                               17
# NWEA_Reading_Growth_Grade_6_Pct                                               34
# NWEA_Reading_Growth_Grade_7_Pct                                               57
# NWEA_Reading_Growth_Grade_8_Pct                                               64
# NWEA_Math_Growth_Grade_3_Pct                                                   3
# NWEA_Math_Growth_Grade_4_Pct                                                  16
# NWEA_Math_Growth_Grade_5_Pct                                                  91
# NWEA_Math_Growth_Grade_6_Pct                                                  30
# NWEA_Math_Growth_Grade_7_Pct                                                  40
# NWEA_Math_Growth_Grade_8_Pct                                                  13
# NWEA_Reading_Attainment_Grade_2_Pct                                           29
# NWEA_Reading_Attainment_Grade_3_Pct                                            9
# NWEA_Reading_Attainment_Grade_4_Pct                                            6
# NWEA_Reading_Attainment_Grade_5_Pct                                           26
# NWEA_Reading_Attainment_Grade_6_Pct                                           10
# NWEA_Reading_Attainment_Grade_7_Pct                                           21
# NWEA_Reading_Attainment_Grade_8_Pct                                           53
# NWEA_Math_Attainment_Grade_2_Pct                                              35
# NWEA_Math_Attainment_Grade_3_Pct                                               8
# NWEA_Math_Attainment_Grade_4_Pct                                              28
# NWEA_Math_Attainment_Grade_5_Pct                                              29
# NWEA_Math_Attainment_Grade_6_Pct                                              19
# NWEA_Math_Attainment_Grade_7_Pct                                              15
# NWEA_Math_Attainment_Grade_8_Pct                                              31
# School_Survey_Involved_Families                                             WEAK
# School_Survey_Supportive_Environment                                     NEUTRAL
# School_Survey_Ambitious_Instruction                                      NEUTRAL
# School_Survey_Effective_Leaders                                        VERY WEAK
# School_Survey_Collaborative_Teachers                                        WEAK
# School_Survey_Safety                                                        WEAK
# Suspensions_Per_100_Students_Year_1_Pct                                     32.3
# Suspensions_Per_100_Students_Year_2_Pct                                        4
# Suspensions_Per_100_Students_Avg_Pct                                         3.8
# Misconducts_To_Suspensions_Year_1_Pct                                       86.5
# Misconducts_To_Suspensions_Year_2_Pct                                       14.2
# Misconducts_To_Suspensions_Avg_Pct                                          18.4
# Average_Length_Suspension_Year_1_Pct                                    2.3 days
# Average_Length_Suspension_Year_2_Pct                                    3.9 days
# Average_Length_Suspension_Avg_Pct                                       2.1 days
# Behavior_Discipline_Year_1                                                  2014
# Behavior_Discipline_Year_2                                                  2015
# School_Survey_School_Community                                            Strong
# School_Survey_Parent_Teacher_Partnership                                  Strong
# School_Survey_Quality_Of_Facilities                                  Very strong
# Student_Attendance_Year_1_Pct                                               95.8
# Student_Attendance_Year_2_Pct                                               95.9
# Student_Attendance_Avg_Pct                                                  95.1
# Teacher_Attendance_Year_1_Pct                                               96.6
# Teacher_Attendance_Year_2_Pct                                               95.5
# Teacher_Attendance_Avg_Pct                                                    95
# One_Year_Dropout_Rate_Year_1_Pct                                             NaN
# One_Year_Dropout_Rate_Year_2_Pct                                             NaN
# One_Year_Dropout_Rate_Avg_Pct                                                7.9
# Mobility_Rate_Pct                                                           25.5
# Chronic_Truancy_Pct                                                          NaN
# Supportive_School_Award                                                NOT RATED
# School_Latitude                                                          41.7589
# School_Longitude                                                        -87.6492
#
#                                                                          1880  \
# index                                                                     665
# School_ID                                                              610173
# Long_Name                                    Jesse Sherwood Elementary School
# School_Type                                                      Neighborhood
# Primary_Category                                                           ES
# Progress_Report_Year                                                     2015
# Blue_Ribbon_Award_Year                                                    NaN
# Excelerate_Award_Gold_Year                                                NaN
# Spot_Light_Award_Year                                                     NaN
# Improvement_Award_Year                                                    NaN
# Excellence_Award_Year                                                     NaN
# Student_Growth_Rating                                       FAR ABOVE AVERAGE
# Growth_Reading_Grades_Tested_Pct_ES                                        99
# Growth_Math_Grades_Tested_Pct_ES                                           99
# Student_Attainment_Rating                                   FAR ABOVE AVERAGE
# Attainment_Reading_Pct_ES                                                  96
# Attainment_Math_Pct_ES                                                     93
# Culture_Climate_Rating                                         WELL ORGANIZED
# School_Survey_Student_Response_Rate_Pct                                  99.9
# School_Survey_Student_Response_Rate_Avg_Pct                              81.2
# School_Survey_Teacher_Response_Rate_Pct                                  95.8
# School_Survey_Teacher_Response_Rate_Avg_Pct                              80.7
# School_Survey_Parent_Response_Rate_Pct                                    NaN
# Healthy_School_Certification                                    NOT CERTIFIED
# Creative_School_Certification                                       EXCELLING
# NWEA_Reading_Growth_Grade_3_Pct                                            99
# NWEA_Reading_Growth_Grade_4_Pct                                            99
# NWEA_Reading_Growth_Grade_5_Pct                                            99
# NWEA_Reading_Growth_Grade_6_Pct                                            99
# NWEA_Reading_Growth_Grade_7_Pct                                            99
# NWEA_Reading_Growth_Grade_8_Pct                                            79
# NWEA_Math_Growth_Grade_3_Pct                                               99
# NWEA_Math_Growth_Grade_4_Pct                                               99
# NWEA_Math_Growth_Grade_5_Pct                                               99
# NWEA_Math_Growth_Grade_6_Pct                                               99
# NWEA_Math_Growth_Grade_7_Pct                                               99
# NWEA_Math_Growth_Grade_8_Pct                                               99
# NWEA_Reading_Attainment_Grade_2_Pct                                        95
# NWEA_Reading_Attainment_Grade_3_Pct                                        86
# NWEA_Reading_Attainment_Grade_4_Pct                                        99
# NWEA_Reading_Attainment_Grade_5_Pct                                        97
# NWEA_Reading_Attainment_Grade_6_Pct                                        88
# NWEA_Reading_Attainment_Grade_7_Pct                                        73
# NWEA_Reading_Attainment_Grade_8_Pct                                        58
# NWEA_Math_Attainment_Grade_2_Pct                                           99
# NWEA_Math_Attainment_Grade_3_Pct                                           82
# NWEA_Math_Attainment_Grade_4_Pct                                           99
# NWEA_Math_Attainment_Grade_5_Pct                                           75
# NWEA_Math_Attainment_Grade_6_Pct                                           82
# NWEA_Math_Attainment_Grade_7_Pct                                           88
# NWEA_Math_Attainment_Grade_8_Pct                                           74
# School_Survey_Involved_Families                                       NEUTRAL
# School_Survey_Supportive_Environment                              VERY STRONG
# School_Survey_Ambitious_Instruction                               VERY STRONG
# School_Survey_Effective_Leaders                                        STRONG
# School_Survey_Collaborative_Teachers                                   STRONG
# School_Survey_Safety                                                   STRONG
# Suspensions_Per_100_Students_Year_1_Pct                                   5.8
# Suspensions_Per_100_Students_Year_2_Pct                                   1.7
# Suspensions_Per_100_Students_Avg_Pct                                      3.8
# Misconducts_To_Suspensions_Year_1_Pct                                    62.2
# Misconducts_To_Suspensions_Year_2_Pct                                    18.2
# Misconducts_To_Suspensions_Avg_Pct                                       18.4
# Average_Length_Suspension_Year_1_Pct                                 2.7 days
# Average_Length_Suspension_Year_2_Pct                                 2.7 days
# Average_Length_Suspension_Avg_Pct                                    2.1 days
# Behavior_Discipline_Year_1                                               2014
# Behavior_Discipline_Year_2                                               2015
# School_Survey_School_Community                                         Strong
# School_Survey_Parent_Teacher_Partnership                              Neutral
# School_Survey_Quality_Of_Facilities                                    Strong
# Student_Attendance_Year_1_Pct                                              95
# Student_Attendance_Year_2_Pct                                            95.9
# Student_Attendance_Avg_Pct                                               95.1
# Teacher_Attendance_Year_1_Pct                                            97.6
# Teacher_Attendance_Year_2_Pct                                            96.3
# Teacher_Attendance_Avg_Pct                                                 95
# One_Year_Dropout_Rate_Year_1_Pct                                          NaN
# One_Year_Dropout_Rate_Year_2_Pct                                          NaN
# One_Year_Dropout_Rate_Avg_Pct                                             7.9
# Mobility_Rate_Pct                                                        32.3
# Chronic_Truancy_Pct                                                       NaN
# Supportive_School_Award                                             NOT RATED
# School_Latitude                                                       41.7908
# School_Longitude                                                     -87.6323
#
#                                                                      1881  \
# index                                                                 666
# School_ID                                                          610115
# Long_Name                                    Park Manor Elementary School
# School_Type                                                  Neighborhood
# Primary_Category                                                       ES
# Progress_Report_Year                                                 2015
# Blue_Ribbon_Award_Year                                                NaN
# Excelerate_Award_Gold_Year                                            NaN
# Spot_Light_Award_Year                                                 NaN
# Improvement_Award_Year                                               2012
# Excellence_Award_Year                                                 NaN
# Student_Growth_Rating                                             AVERAGE
# Growth_Reading_Grades_Tested_Pct_ES                                    43
# Growth_Math_Grades_Tested_Pct_ES                                       31
# Student_Attainment_Rating                                   BELOW AVERAGE
# Attainment_Reading_Pct_ES                                              24
# Attainment_Math_Pct_ES                                                 25
# Culture_Climate_Rating                                     WELL ORGANIZED
# School_Survey_Student_Response_Rate_Pct                              87.7
# School_Survey_Student_Response_Rate_Avg_Pct                          81.2
# School_Survey_Teacher_Response_Rate_Pct                              73.7
# School_Survey_Teacher_Response_Rate_Avg_Pct                          80.7
# School_Survey_Parent_Response_Rate_Pct                                NaN
# Healthy_School_Certification                                NOT CERTIFIED
# Creative_School_Certification                                  DEVELOPING
# NWEA_Reading_Growth_Grade_3_Pct                                        66
# NWEA_Reading_Growth_Grade_4_Pct                                        74
# NWEA_Reading_Growth_Grade_5_Pct                                         3
# NWEA_Reading_Growth_Grade_6_Pct                                        57
# NWEA_Reading_Growth_Grade_7_Pct                                        71
# NWEA_Reading_Growth_Grade_8_Pct                                        16
# NWEA_Math_Growth_Grade_3_Pct                                            1
# NWEA_Math_Growth_Grade_4_Pct                                            2
# NWEA_Math_Growth_Grade_5_Pct                                           30
# NWEA_Math_Growth_Grade_6_Pct                                           81
# NWEA_Math_Growth_Grade_7_Pct                                           95
# NWEA_Math_Growth_Grade_8_Pct                                           60
# NWEA_Reading_Attainment_Grade_2_Pct                                    40
# NWEA_Reading_Attainment_Grade_3_Pct                                    25
# NWEA_Reading_Attainment_Grade_4_Pct                                    23
# NWEA_Reading_Attainment_Grade_5_Pct                                     7
# NWEA_Reading_Attainment_Grade_6_Pct                                    30
# NWEA_Reading_Attainment_Grade_7_Pct                                    58
# NWEA_Reading_Attainment_Grade_8_Pct                                    19
# NWEA_Math_Attainment_Grade_2_Pct                                       36
# NWEA_Math_Attainment_Grade_3_Pct                                        4
# NWEA_Math_Attainment_Grade_4_Pct                                        6
# NWEA_Math_Attainment_Grade_5_Pct                                       16
# NWEA_Math_Attainment_Grade_6_Pct                                       34
# NWEA_Math_Attainment_Grade_7_Pct                                       67
# NWEA_Math_Attainment_Grade_8_Pct                                       66
# School_Survey_Involved_Families                                    STRONG
# School_Survey_Supportive_Environment                               STRONG
# School_Survey_Ambitious_Instruction                           VERY STRONG
# School_Survey_Effective_Leaders                                    STRONG
# School_Survey_Collaborative_Teachers                          VERY STRONG
# School_Survey_Safety                                                 WEAK
# Suspensions_Per_100_Students_Year_1_Pct                               2.9
# Suspensions_Per_100_Students_Year_2_Pct                               3.7
# Suspensions_Per_100_Students_Avg_Pct                                  3.8
# Misconducts_To_Suspensions_Year_1_Pct                                47.6
# Misconducts_To_Suspensions_Year_2_Pct                                48.3
# Misconducts_To_Suspensions_Avg_Pct                                   18.4
# Average_Length_Suspension_Year_1_Pct                             3.0 days
# Average_Length_Suspension_Year_2_Pct                             3.1 days
# Average_Length_Suspension_Avg_Pct                                2.1 days
# Behavior_Discipline_Year_1                                           2014
# Behavior_Discipline_Year_2                                           2015
# School_Survey_School_Community                                        NaN
# School_Survey_Parent_Teacher_Partnership                              NaN
# School_Survey_Quality_Of_Facilities                                   NaN
# Student_Attendance_Year_1_Pct                                          96
# Student_Attendance_Year_2_Pct                                        96.1
# Student_Attendance_Avg_Pct                                           95.1
# Teacher_Attendance_Year_1_Pct                                        95.5
# Teacher_Attendance_Year_2_Pct                                        96.1
# Teacher_Attendance_Avg_Pct                                             95
# One_Year_Dropout_Rate_Year_1_Pct                                      NaN
# One_Year_Dropout_Rate_Year_2_Pct                                      NaN
# One_Year_Dropout_Rate_Avg_Pct                                         7.9
# Mobility_Rate_Pct                                                    41.2
# Chronic_Truancy_Pct                                                   NaN
# Supportive_School_Award                                         NOT RATED
# School_Latitude                                                   41.7665
# School_Longitude                                                 -87.6115
#
#                                                                            1882  \
# index                                                                       667
# School_ID                                                                609996
# Long_Name                                    Charles N Holden Elementary School
# School_Type                                                        Neighborhood
# Primary_Category                                                             ES
# Progress_Report_Year                                                       2015
# Blue_Ribbon_Award_Year                                                      NaN
# Excelerate_Award_Gold_Year                                                 2015
# Spot_Light_Award_Year                                                       NaN
# Improvement_Award_Year                                                      NaN
# Excellence_Award_Year                                                       NaN
# Student_Growth_Rating                                         FAR ABOVE AVERAGE
# Growth_Reading_Grades_Tested_Pct_ES                                          71
# Growth_Math_Grades_Tested_Pct_ES                                             93
# Student_Attainment_Rating                                         ABOVE AVERAGE
# Attainment_Reading_Pct_ES                                                    58
# Attainment_Math_Pct_ES                                                       81
# Culture_Climate_Rating                                           WELL ORGANIZED
# School_Survey_Student_Response_Rate_Pct                                    88.6
# School_Survey_Student_Response_Rate_Avg_Pct                                81.2
# School_Survey_Teacher_Response_Rate_Pct                                    90.3
# School_Survey_Teacher_Response_Rate_Avg_Pct                                80.7
# School_Survey_Parent_Response_Rate_Pct                                      NaN
# Healthy_School_Certification                                      NOT CERTIFIED
# Creative_School_Certification                                         EXCELLING
# NWEA_Reading_Growth_Grade_3_Pct                                              28
# NWEA_Reading_Growth_Grade_4_Pct                                              38
# NWEA_Reading_Growth_Grade_5_Pct                                              58
# NWEA_Reading_Growth_Grade_6_Pct                                              95
# NWEA_Reading_Growth_Grade_7_Pct                                              90
# NWEA_Reading_Growth_Grade_8_Pct                                              62
# NWEA_Math_Growth_Grade_3_Pct                                                 20
# NWEA_Math_Growth_Grade_4_Pct                                                 99
# NWEA_Math_Growth_Grade_5_Pct                                                 42
# NWEA_Math_Growth_Grade_6_Pct                                                 83
# NWEA_Math_Growth_Grade_7_Pct                                                 99
# NWEA_Math_Growth_Grade_8_Pct                                                 99
# NWEA_Reading_Attainment_Grade_2_Pct                                          38
# NWEA_Reading_Attainment_Grade_3_Pct                                          55
# NWEA_Reading_Attainment_Grade_4_Pct                                          51
# NWEA_Reading_Attainment_Grade_5_Pct                                          50
# NWEA_Reading_Attainment_Grade_6_Pct                                          60
# NWEA_Reading_Attainment_Grade_7_Pct                                          73
# NWEA_Reading_Attainment_Grade_8_Pct                                          66
# NWEA_Math_Attainment_Grade_2_Pct                                             53
# NWEA_Math_Attainment_Grade_3_Pct                                             43
# NWEA_Math_Attainment_Grade_4_Pct                                             75
# NWEA_Math_Attainment_Grade_5_Pct                                             51
# NWEA_Math_Attainment_Grade_6_Pct                                             83
# NWEA_Math_Attainment_Grade_7_Pct                                             97
# NWEA_Math_Attainment_Grade_8_Pct                                             97
# School_Survey_Involved_Families                                          STRONG
# School_Survey_Supportive_Environment                                     STRONG
# School_Survey_Ambitious_Instruction                                      STRONG
# School_Survey_Effective_Leaders                                         NEUTRAL
# School_Survey_Collaborative_Teachers                                     STRONG
# School_Survey_Safety                                                    NEUTRAL
# Suspensions_Per_100_Students_Year_1_Pct                                     4.4
# Suspensions_Per_100_Students_Year_2_Pct                                       3
# Suspensions_Per_100_Students_Avg_Pct                                        3.8
# Misconducts_To_Suspensions_Year_1_Pct                                      61.5
# Misconducts_To_Suspensions_Year_2_Pct                                      28.1
# Misconducts_To_Suspensions_Avg_Pct                                         18.4
# Average_Length_Suspension_Year_1_Pct                                   2.5 days
# Average_Length_Suspension_Year_2_Pct                                   1.9 days
# Average_Length_Suspension_Avg_Pct                                      2.1 days
# Behavior_Discipline_Year_1                                                 2014
# Behavior_Discipline_Year_2                                                 2015
# School_Survey_School_Community                                          Neutral
# School_Survey_Parent_Teacher_Partnership                                Neutral
# School_Survey_Quality_Of_Facilities                                     Neutral
# Student_Attendance_Year_1_Pct                                              94.5
# Student_Attendance_Year_2_Pct                                              94.8
# Student_Attendance_Avg_Pct                                                 95.1
# Teacher_Attendance_Year_1_Pct                                              95.5
# Teacher_Attendance_Year_2_Pct                                              94.3
# Teacher_Attendance_Avg_Pct                                                   95
# One_Year_Dropout_Rate_Year_1_Pct                                            NaN
# One_Year_Dropout_Rate_Year_2_Pct                                            NaN
# One_Year_Dropout_Rate_Avg_Pct                                               7.9
# Mobility_Rate_Pct                                                          14.2
# Chronic_Truancy_Pct                                                         NaN
# Supportive_School_Award                                               NOT RATED
# School_Latitude                                                          41.838
# School_Longitude                                                       -87.6538
#
#                                                                                    1883
# index                                                                               668
# School_ID                                                                        609815
# Long_Name                                    Edward A Bouchet Math & Science Academy ES
# School_Type                                                                Neighborhood
# Primary_Category                                                                     ES
# Progress_Report_Year                                                               2015
# Blue_Ribbon_Award_Year                                                              NaN
# Excelerate_Award_Gold_Year                                                          NaN
# Spot_Light_Award_Year                                                               NaN
# Improvement_Award_Year                                                              NaN
# Excellence_Award_Year                                                               NaN
# Student_Growth_Rating                                                     ABOVE AVERAGE
# Growth_Reading_Grades_Tested_Pct_ES                                                  95
# Growth_Math_Grades_Tested_Pct_ES                                                     67
# Student_Attainment_Rating                                                       AVERAGE
# Attainment_Reading_Pct_ES                                                            52
# Attainment_Math_Pct_ES                                                               39
# Culture_Climate_Rating                                                   WELL ORGANIZED
# School_Survey_Student_Response_Rate_Pct                                            99.9
# School_Survey_Student_Response_Rate_Avg_Pct                                        81.2
# School_Survey_Teacher_Response_Rate_Pct                                            99.9
# School_Survey_Teacher_Response_Rate_Avg_Pct                                        80.7
# School_Survey_Parent_Response_Rate_Pct                                              NaN
# Healthy_School_Certification                                  HEALTHY SCHOOLS CERTIFIED
# Creative_School_Certification                                                 EXCELLING
# NWEA_Reading_Growth_Grade_3_Pct                                                      81
# NWEA_Reading_Growth_Grade_4_Pct                                                      99
# NWEA_Reading_Growth_Grade_5_Pct                                                      58
# NWEA_Reading_Growth_Grade_6_Pct                                                      78
# NWEA_Reading_Growth_Grade_7_Pct                                                      92
# NWEA_Reading_Growth_Grade_8_Pct                                                      93
# NWEA_Math_Growth_Grade_3_Pct                                                         64
# NWEA_Math_Growth_Grade_4_Pct                                                         99
# NWEA_Math_Growth_Grade_5_Pct                                                         60
# NWEA_Math_Growth_Grade_6_Pct                                                         44
# NWEA_Math_Growth_Grade_7_Pct                                                         22
# NWEA_Math_Growth_Grade_8_Pct                                                         60
# NWEA_Reading_Attainment_Grade_2_Pct                                                  33
# NWEA_Reading_Attainment_Grade_3_Pct                                                  39
# NWEA_Reading_Attainment_Grade_4_Pct                                                  64
# NWEA_Reading_Attainment_Grade_5_Pct                                                  42
# NWEA_Reading_Attainment_Grade_6_Pct                                                  48
# NWEA_Reading_Attainment_Grade_7_Pct                                                  71
# NWEA_Reading_Attainment_Grade_8_Pct                                                  74
# NWEA_Math_Attainment_Grade_2_Pct                                                     33
# NWEA_Math_Attainment_Grade_3_Pct                                                     24
# NWEA_Math_Attainment_Grade_4_Pct                                                     63
# NWEA_Math_Attainment_Grade_5_Pct                                                     29
# NWEA_Math_Attainment_Grade_6_Pct                                                     21
# NWEA_Math_Attainment_Grade_7_Pct                                                     57
# NWEA_Math_Attainment_Grade_8_Pct                                                     63
# School_Survey_Involved_Families                                             VERY STRONG
# School_Survey_Supportive_Environment                                        VERY STRONG
# School_Survey_Ambitious_Instruction                                         VERY STRONG
# School_Survey_Effective_Leaders                                                  STRONG
# School_Survey_Collaborative_Teachers                                        VERY STRONG
# School_Survey_Safety                                                            NEUTRAL
# Suspensions_Per_100_Students_Year_1_Pct                                            20.7
# Suspensions_Per_100_Students_Year_2_Pct                                             9.4
# Suspensions_Per_100_Students_Avg_Pct                                                3.8
# Misconducts_To_Suspensions_Year_1_Pct                                              82.4
# Misconducts_To_Suspensions_Year_2_Pct                                              24.1
# Misconducts_To_Suspensions_Avg_Pct                                                 18.4
# Average_Length_Suspension_Year_1_Pct                                           1.9 days
# Average_Length_Suspension_Year_2_Pct                                           2.2 days
# Average_Length_Suspension_Avg_Pct                                              2.1 days
# Behavior_Discipline_Year_1                                                         2014
# Behavior_Discipline_Year_2                                                         2015
# School_Survey_School_Community                                                  Neutral
# School_Survey_Parent_Teacher_Partnership                                         Strong
# School_Survey_Quality_Of_Facilities                                              Strong
# Student_Attendance_Year_1_Pct                                                        94
# Student_Attendance_Year_2_Pct                                                      93.9
# Student_Attendance_Avg_Pct                                                         95.1
# Teacher_Attendance_Year_1_Pct                                                      96.2
# Teacher_Attendance_Year_2_Pct                                                      95.8
# Teacher_Attendance_Avg_Pct                                                           95
# One_Year_Dropout_Rate_Year_1_Pct                                                    NaN
# One_Year_Dropout_Rate_Year_2_Pct                                                    NaN
# One_Year_Dropout_Rate_Avg_Pct                                                       7.9
# Mobility_Rate_Pct                                                                  32.8
# Chronic_Truancy_Pct                                                                 NaN
# Supportive_School_Award                                                       NOT RATED
# School_Latitude                                                                 41.7608
# School_Longitude                                                               -87.5761

# %%
df_raw.shape
# Out:
# (1884, 85)

# %% [markdown]
# Since we have already utilized the data present in Primary Category, we can drop that column.  I will also remove a few average percentage columns that slipped through the cracks so far but hold only a single value per calendar year.

# %%
df_raw.drop(['index','Average_Length_Suspension_Avg_Pct','Teacher_Attendance_Avg_Pct','Suspensions_Per_100_Students_Avg_Pct','Student_Attendance_Avg_Pct','One_Year_Dropout_Rate_Avg_Pct'], axis = 1, inplace = True)

# %% [markdown]
# ## Dataset Exporting for SQL Table Creation
#
# To leverage this dataset for ad hoc analysis, I will export it into a set of csv files that would easily allow for creating a SQL database.  To start, I'll take out the school location data and place it into a seperate table for export.

# %%
#export data
lat_long_df = df_raw[['School_ID', 'School_Latitude', 'School_Longitude']].copy()

#drop NaN values
lat_long_df.dropna(subset = ['School_Latitude','School_Longitude'], inplace = True)

#dedupe list
lat_long_df.drop_duplicates(inplace = True)

#push list to csv
lat_long_df.to_csv(f'{PATH}SQL/school_locations.csv', index = False)

# %% [markdown]
# With this data exported, I will use this table to fill in missing location values in `df_raw`.

# %%
df_raw.loc[10,'School_Latitude']
# Out:
# nan

# %%
lat_long_df.loc[lat_long_df.School_ID == 610115, 'School_Latitude']
# Out:
# 1091    41.766477
# Name: School_Latitude, dtype: float64

# %%
lat_long_df.set_index('School_ID')['School_Latitude']
# Out:
# School_ID
# 610104    41.993790
# 610070    41.967847
# 610251    41.882950
# 610268    41.740184
# 610089    41.950078
#             ...
# 609821    41.714402
# 610305    41.873587
# 609874    41.973715
# 610584    41.883606
# 400072    41.752458
# Name: School_Latitude, Length: 472, dtype: float64

# %%
df_raw.School_ID.nunique()
# Out:
# 476

# %%
df1['Weight'] = df1['ID'].map(df2.set_index('ID')['Value'])

# %%
df_raw['School_Latitude'] = lat_long_df.map()

# %%
df_raw.tail()
# Out:
#       School_ID                                   Long_Name   School_Type  \
# 1879     610339         Amos Alonzo Stagg Elementary School  Neighborhood
# 1880     610173            Jesse Sherwood Elementary School  Neighborhood
# 1881     610115                Park Manor Elementary School  Neighborhood
# 1882     609996          Charles N Holden Elementary School  Neighborhood
# 1883     609815  Edward A Bouchet Math & Science Academy ES  Neighborhood
#
#      Primary_Category  Progress_Report_Year  Blue_Ribbon_Award_Year  \
# 1879               ES                  2015                     NaN
# 1880               ES                  2015                     NaN
# 1881               ES                  2015                     NaN
# 1882               ES                  2015                     NaN
# 1883               ES                  2015                     NaN
#
#       Excelerate_Award_Gold_Year  Spot_Light_Award_Year  \
# 1879                         NaN                    NaN
# 1880                         NaN                    NaN
# 1881                         NaN                    NaN
# 1882                      2015.0                    NaN
# 1883                         NaN                    NaN
#
#       Improvement_Award_Year  Excellence_Award_Year  ...  \
# 1879                     NaN                    NaN  ...
# 1880                     NaN                    NaN  ...
# 1881                  2012.0                    NaN  ...
# 1882                     NaN                    NaN  ...
# 1883                     NaN                    NaN  ...
#
#      Student_Attendance_Year_2_Pct  Teacher_Attendance_Year_1_Pct  \
# 1879                          95.9                           96.6
# 1880                          95.9                           97.6
# 1881                          96.1                           95.5
# 1882                          94.8                           95.5
# 1883                          93.9                           96.2
#
#       Teacher_Attendance_Year_2_Pct One_Year_Dropout_Rate_Year_1_Pct  \
# 1879                           95.5                              NaN
# 1880                           96.3                              NaN
# 1881                           96.1                              NaN
# 1882                           94.3                              NaN
# 1883                           95.8                              NaN
#
#       One_Year_Dropout_Rate_Year_2_Pct  Mobility_Rate_Pct Chronic_Truancy_Pct  \
# 1879                               NaN               25.5                 NaN
# 1880                               NaN               32.3                 NaN
# 1881                               NaN               41.2                 NaN
# 1882                               NaN               14.2                 NaN
# 1883                               NaN               32.8                 NaN
#
#       Supportive_School_Award  School_Latitude  School_Longitude
# 1879                NOT RATED          unknown        -87.649217
# 1880                NOT RATED          unknown        -87.632279
# 1881                NOT RATED          unknown        -87.611546
# 1882                NOT RATED          unknown        -87.653792
# 1883                NOT RATED          unknown        -87.576075
#
# [5 rows x 79 columns]

# %%
df_raw.to_csv(f'{PATH}report_card_2015-2019.csv')

# %% [markdown]
# # Joined Dataset Preprocessing
#
# With this data now purged, I will now address the various categorical columns and prepare them for processing by the ``RandomForestClassifier()`` - using the `DataFrameSummary()` package will make this process much easier.  But first, I will eliminate the whitespace that appears at the end of some of the column names to make future column references easier to manage.

# %%
df_raw.columns = [col.strip() for col in df_raw.columns]

# %%
dfs = DataFrameSummary(df_raw)

# %%
dfs.columns_types

# %% [markdown]
# ## Boolean Column Preprocessing
#
# Starting with the smallest subset of values, I will examine the boolean columns first.

# %%
dfs.bools

# %%
df_raw.Spot_Light_Award_Year.value_counts()

# %% [markdown]
# Since there are so few schools who won this award - and one can only presume that having received the award in 2012 vs 2013 would make little difference - I will convert this column into an indicator variable.

# %%
df_raw['Won_Spot_Light_Award'] = 0
df_raw.loc[df_raw.Spot_Light_Award_Year.notnull(), 'Won_Spot_Light_Award'] = 1
df_raw.drop('Spot_Light_Award_Year', axis = 1, inplace = True)
df_raw.Won_Spot_Light_Award.value_counts()

# %% [markdown]
# After confirming that this column has been transformed, I dropped the original column.  I will now examine the other boolean columns as well as other "Award Year" columns.  Assuming these columns are also easily transformed into indicator variables, I will create a new column indicating if the award had been given and then drop the original column.

# %%
df_raw.Improvement_Award_Year.value_counts()

# %%
df_raw['Won_Improvement_Award'] = 0
df_raw.loc[df_raw.Improvement_Award_Year.notnull(), 'Won_Improvement_Award'] = 1
df_raw.drop('Improvement_Award_Year', axis = 1, inplace = True)
df_raw.Won_Improvement_Award.value_counts()

# %%
df_raw.Excellence_Award_Year.value_counts()

# %%
df_raw['Won_Excellence_Award'] = 0
df_raw.loc[df_raw.Excellence_Award_Year.notnull(), 'Won_Excellence_Award'] = 1
df_raw.drop('Excellence_Award_Year', axis = 1, inplace = True)
df_raw.Won_Excellence_Award.value_counts()

# %%
df_raw.Blue_Ribbon_Award_Year.value_counts()

# %%
df_raw['Won_Blue_Ribbon_Award'] = 0
df_raw.loc[df_raw.Blue_Ribbon_Award_Year.notnull(), 'Won_Blue_Ribbon_Award'] = 1
df_raw.drop('Blue_Ribbon_Award_Year', axis = 1, inplace = True)
df_raw.Won_Blue_Ribbon_Award.value_counts()

# %%
df_raw.Excelerate_Award_Gold_Year.value_counts()

# %%
df_raw['Won_Excelerate_Award_Gold'] = 0
df_raw.loc[df_raw.Excelerate_Award_Gold_Year.notnull(), 'Won_Excelerate_Award_Gold'] = 1
df_raw.drop('Excelerate_Award_Gold_Year', axis = 1, inplace = True)
df_raw.Won_Excelerate_Award_Gold.value_counts()

# %% [markdown]
# ## Categorical Column Preprocessing
#
# With these boolean columns now dispositioned for analysis, I turn my attention to the categorical columns.

# %%
dfs.categoricals

# %% [markdown]
# In this list of categoricals, we see a few entries that clearly appear to be numerical.  I will examine these entries and make the necessary changes  so the values are properly represented in numerical columns.

# %%
df_raw.Average_Length_Suspension_Year_1_Pct.value_counts()

# %%
for idx, val in df_raw.iterrows():
    try:
        df_raw.loc[idx,'Average_Length_Suspension_Year_1_Pct'] = df_raw.Average_Length_Suspension_Year_1_Pct.loc[idx].replace(' days', '')
    except:
        pass
    try:
        df_raw.loc[idx,'Average_Length_Suspension_Year_2_Pct'] = df_raw.Average_Length_Suspension_Year_2_Pct.loc[idx].replace(' days', '')
    except:
        pass

# %%
sum(df_raw.Average_Length_Suspension_Year_1_Pct.isnull()), sum(df_raw.Average_Length_Suspension_Year_2_Pct.isnull())

# %% [markdown]
# For these two columns, we are not missing an overly signficant number of values.  I will impute the mean for all missing values, but also mark out which schools did not provide this data.

# %%
df_raw["Missing_Suspension_Data"] = 0

df_raw.loc[df_raw.Average_Length_Suspension_Year_1_Pct.isnull(),'Missing_Suspension_Data'] = 1
df_raw.loc[df_raw.Average_Length_Suspension_Year_2_Pct.isnull(),'Missing_Suspension_Data'] = 1

# %%
df_raw.Missing_Suspension_Data.value_counts()

# %%
df_raw.Average_Length_Suspension_Year_1_Pct = df_raw.Average_Length_Suspension_Year_1_Pct.astype('float')
df_raw.Average_Length_Suspension_Year_2_Pct = df_raw.Average_Length_Suspension_Year_2_Pct.astype('float')

# %%
year_1_mean = np.around(df_raw.Average_Length_Suspension_Year_1_Pct.mean(),2)
year_2_mean = np.around(df_raw.Average_Length_Suspension_Year_2_Pct.mean(),2)
year_1_mean, year_2_mean

# %%
df_raw.Average_Length_Suspension_Year_1_Pct.fillna(year_1_mean, inplace = True)
df_raw.Average_Length_Suspension_Year_2_Pct.fillna(year_2_mean, inplace = True)

# %% [markdown]
# I will now address the next column that appears to be misclassified, the 'School_Survey_Parent_Response_Rate_Pct' column.

# %%
df_raw.School_Survey_Parent_Response_Rate_Pct.value_counts()

# %% [markdown]
# In this response rate column, we see a hodgepodge of values.  I will strip the '%' sign from all entries, and assign the ' < 30%' and '> 75%' to 29 and 76, respectively - the Random Forest will be able to detect those differences very easily in assessing this column for predictive value.

# %%
df_raw.loc[df_raw.School_Survey_Parent_Response_Rate_Pct == '< 30%','School_Survey_Parent_Response_Rate_Pct'] = 29
df_raw.loc[df_raw.School_Survey_Parent_Response_Rate_Pct == '> 75%','School_Survey_Parent_Response_Rate_Pct'] = 76
df_raw.loc[df_raw.School_Survey_Parent_Response_Rate_Pct == '.','School_Survey_Parent_Response_Rate_Pct'] = 0
df_raw.loc[df_raw.School_Survey_Parent_Response_Rate_Pct.isnull(),'School_Survey_Parent_Response_Rate_Pct'] = 0
df_raw.School_Survey_Parent_Response_Rate_Pct = df_raw.School_Survey_Parent_Response_Rate_Pct.apply(lambda x: int(str(x).replace('%','')))

# %%
df_raw.School_Survey_Parent_Response_Rate_Pct.value_counts()

# %% [markdown]
# There are a significant number of missing values here - recall from above that this data was either not collected or not reported in the first two school years covered by my analysis - so I will impute the mean for missing values and then tag those rows with missing data.

# %%
mean_rate = round(df_raw.loc[df_raw.School_Survey_Parent_Response_Rate_Pct > 0, 'School_Survey_Parent_Response_Rate_Pct'].mean(), 1)
df_raw['Has_Parent_Response_Rate'] = 1
df_raw.loc[df_raw.School_Survey_Parent_Response_Rate_Pct == 0, 'Has_Parent_Response_Rate'] = 0
df_raw.loc[df_raw.School_Survey_Parent_Response_Rate_Pct == 0, 'School_Survey_Parent_Response_Rate_Pct'] = mean_rate

df_raw.School_Survey_Parent_Response_Rate_Pct.value_counts()

# %%
df_raw.Has_Parent_Response_Rate.value_counts()

# %%
dfs = DataFrameSummary(df_raw)
dfs.categoricals

# %%
df_raw.Supportive_School_Award.value_counts()

# %%
df_raw.Supportive_School_Award = df_raw.Supportive_School_Award.apply(lambda x: x.title())
df_raw.loc[df_raw.Supportive_School_Award == 'Coming Soon','Supportive_School_Award'] = 'Not Rated'

# %%
df_raw.Supportive_School_Award.value_counts()

# %%
def train_cats(df, col_list):
    for col_name in col_list:
        df[col_name] = df[col_name].astype("category")
    return df

# %%
cat_cols = ['School_Type', 'Student_Growth_Rating',
       'Student_Attainment_Rating', 'Culture_Climate_Rating',
       'Healthy_School_Certification', 'Creative_School_Certification',
       'School_Survey_Involved_Families',
       'School_Survey_Supportive_Environment',
       'School_Survey_Ambitious_Instruction',
       'School_Survey_Effective_Leaders',
       'School_Survey_Collaborative_Teachers', 'School_Survey_Safety',
       'School_Survey_School_Community',
       'School_Survey_Parent_Teacher_Partnership',
       'School_Survey_Quality_Of_Facilities', 'Supportive_School_Award']

# %%
df_raw = train_cats(df_raw, cat_cols)

# %% [markdown]
# Many of the categorical columns contain categories that possess an obvious order, but by default, pandas will assign the numerical coding for the category based on an alphabetical ordering.  To override this default, I will reorder the categories in each of these columns in their logical order, i.e. from "Very Weak" to "Very Strong."

# %%
#fix capitalization
df_raw['School_Survey_Quality_Of_Facilities'].value_counts()

# %%
#fix capitalization
df_raw['School_Survey_Parent_Teacher_Partnership'].value_counts()

# %%
#fix capitalization
df_raw['School_Survey_School_Community'].value_counts()

# %%
df_raw['Creative_School_Certification'].value_counts()

# %%
avg_text_vals = ["NO DATA AVAILABLE","FAR BELOW AVERAGE", "BELOW AVERAGE","AVERAGE","ABOVE AVERAGE","FAR ABOVE AVERAGE"]
df_raw['Student_Growth_Rating'].cat.set_categories(avg_text_vals, ordered=True, inplace=True)
df_raw['Student_Attainment_Rating'].cat.set_categories(avg_text_vals, ordered=True, inplace=True)

# %%
df_raw['Culture_Climate_Rating'].value_counts()

# %%
df_raw['Involved Family'].value_counts()

# %%
organized_text_vals = ["NOT YET ORGANIZED","PARTIALLY ORGANIZED", "MODERATELY ORGANIZED","ORGANIZED","WELL-ORGANIZED"]
df_raw['Culture_Climate_Rating'].cat.set_categories(organized_text_vals, ordered=True, inplace=True)

# %%
weak_to_strong_cats = ["VERY WEAK", "WEAK", "NEUTRAL", "STRONG", "VERY STRONG"]

def set_cats_weak_to_strong(df, col_list):
    for col in col_list:
        df[col].cat.set_categories(weak_to_strong_cats, ordered=True, inplace=True)

# %%
col_list = [
    'School_Survey_Involved_Families','School_Survey_Supportive_Environment',
    'School_Survey_Ambitious_Instruction','School_Survey_Effective_Leaders',
    'School_Survey_Collaborative_Teachers','School_Survey_Safety'
           ]

# %%
df_raw['Healthy_School_Certification'].value_counts()

# %%
df_raw["Involved Family"].cat.codes

# %%
df_Raw['Involved Family'] = df.cc.cat.codes

# %% [markdown]
# Since the goal of this project is to predict the overall performance level of the school from the report card data to determine which features of the report card best predict the score, I will drop any rows which lack a value for this column.

# %%
df_raw['CPS Performance Policy Level'].isnull().index

# %%
df_raw.dropna(subset=['CPS Performance Policy Level'], axis = 0, inplace = True).

# %%
df_raw.shape

# %% [markdown]
# With the categorical columns now processed and rows with null values for the predictor variable dropped, I will turn my attention to other columns with missing values.  Pandas will automatically assign an integer value of $-1$ to missing categorical values, so those columns can be considered dispositioned, but I will process missing values for continuous or integer columns by setting the numeric to "0" and also establishing an "_is_missing" column to ensure any predictive value of that number being absent from the dataset is captured by the Random Forest.

# %%
display_all(df_raw.isnull().sum().sort_index()/len(df_raw))

# %%
df_raw["Average Length of Suspension 2012"].iloc[0]

# %%
len(df_raw[df_raw["Average Length of Suspension 2012"].isnull()].index.tolist())

# %%
col = "School Community"
df_raw[df_raw[col].isnull()].index.tolist()

col + "_test"

# %%
def clean_missing_numerical_col(df, col_list):
    for col in col_list:
        new_col_name = col + "_is_missing"
        
        df[new_col_name] = 0
        missing_col_idxes = df[df[col].isnull()].index.tolist()
        for idx in missing_col_idxes:
            df[new_col_name].iloc[idx] = 1
        
        df.col.fillna(0, inplace = True)

# %%
test_col_list = ["Average Length of Suspension 2012"]

clean_missing_numerical_col(df_raw, test_col_list)

# %%
setIconCats(df, icon_cols)

#confirm output
df["Teachers Icon "].cat.categories

# %% [markdown]
# With this forced ordering now in place, I will transform all categoricals into their integer values.

# %%
display_all(df.describe(include='all').T)

# %%
dfs = DataFrameSummary(df_raw)
display_all(dfs.missing_frac)
